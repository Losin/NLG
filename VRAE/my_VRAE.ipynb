# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

from tensorflow.python.layers import core as core_layers
import tensorflow as tf
import numpy as np
import time
import myResidualCell
from tensorflow.python.ops import array_ops
import jieba
from bleu import BLEU
import random
import cPickle
import matplotlib.pyplot as plt


class VRAE:
    def __init__(self, dp, rnn_size, n_layers, latent_dim, encoder_embedding_dim, decoder_embedding_dim, max_infer_length,
                 sess=tf.Session(), lr=0.001, grad_clip=5.0, beam_width=5, force_teaching_ratio=1.0, beam_penalty=1.0,
                residual=False, output_keep_prob=0.5, input_keep_prob=0.9, cell_type='lstm', reverse=False,
                latent_weight=0.1, beta_decay_period=3, beta_decay_offset=2, decay_scheme='luong234', is_save=True):
        
        self.rnn_size = rnn_size
        self.latent_dim = latent_dim
        self.n_layers = n_layers
        self.grad_clip = grad_clip
        self.dp = dp
        self.step = 0
        self.encoder_embedding_dim = encoder_embedding_dim
        self.decoder_embedding_dim = decoder_embedding_dim
        self.beam_width = beam_width
        self.latent_weight = latent_weight
        self.beam_penalty = beam_penalty
        self.max_infer_length = max_infer_length
        self.residual = residual
        self.is_save = is_save
        self.decay_scheme = decay_scheme
        if self.residual:
            assert encoder_embedding_dim == rnn_size
            assert decoder_embedding_dim == rnn_size
        self.reverse = reverse
        self.cell_type = cell_type
        self.force_teaching_ratio = force_teaching_ratio
        self._output_keep_prob = output_keep_prob
        self._input_keep_prob = input_keep_prob
        self.beta_decay_period = beta_decay_period
        self.beta_decay_offset = beta_decay_offset
        self.sess = sess
        self.lr=lr
        self.build_graph()
        self.sess.run(tf.global_variables_initializer())
        self.saver = tf.train.Saver(tf.global_variables(), max_to_keep = 10)
        self.summary_placeholders, self.update_ops, self.summary_op = self.setup_summary()
        
    # end constructor

    def build_graph(self):
        self.register_symbols()
        self.add_input_layer()
        self.add_encoder_layer()
        self.add_stochastic_layer()
        self.add_decoder_hidden()
        with tf.variable_scope('decode'):
            self.add_decoder_for_training()
        with tf.variable_scope('decode', reuse=True):
            self.add_decoder_for_inference()
        with tf.variable_scope('decode', reuse=True):
            self.add_decoder_for_prefix_inference()
        self.add_backward_path()
    # end method

    def add_input_layer(self):
        self.X = tf.placeholder(tf.int32, [None, None], name="X")
        self.Y = tf.placeholder(tf.int32, [None, None], name="Y")
        self.X_seq_len = tf.placeholder(tf.int32, [None], name="X_seq_len")
        self.Y_seq_len = tf.placeholder(tf.int32, [None], name="Y_seq_len")
        self.input_keep_prob = tf.placeholder(tf.float32,name="input_keep_prob")
        self.output_keep_prob = tf.placeholder(tf.float32,name="output_keep_prob")
        self.batch_size = tf.shape(self.X)[0]
        self.B = tf.placeholder(tf.float32, name='Beta_deterministic_warmup')
        self.global_step = tf.Variable(0, name="global_step", trainable=False)
    # end method

    def single_cell(self, reuse=False):
        if self.cell_type == 'lstm':
             cell = tf.contrib.rnn.LayerNormBasicLSTMCell(self.rnn_size, reuse=reuse)
        else:
            cell = tf.contrib.rnn.GRUBlockCell(self.rnn_size)    
        cell = tf.contrib.rnn.DropoutWrapper(cell, self.output_keep_prob, self.input_keep_prob)
        if self.residual:
            cell = myResidualCell.ResidualWrapper(cell)
        return cell
    
    def add_encoder_layer(self):
        encoder_embedding = tf.get_variable('encoder_embedding', [len(self.dp.X_w2id), self.encoder_embedding_dim],
                                             tf.float32, tf.random_uniform_initializer(-1.0, 1.0))
        
        self.encoder_inputs = tf.nn.embedding_lookup(encoder_embedding, self.X)
        bi_encoder_output, bi_encoder_state = tf.nn.bidirectional_dynamic_rnn(
            cell_fw = tf.contrib.rnn.MultiRNNCell([self.single_cell() for _ in range(self.n_layers)]), 
            cell_bw = tf.contrib.rnn.MultiRNNCell([self.single_cell() for _ in range(self.n_layers)]),
            inputs = self.encoder_inputs,
            sequence_length = self.X_seq_len,
            dtype = tf.float32,
            scope = 'bidirectional_rnn')
        #print bi_encoder_state
        if self.cell_type == 'lstm':
            self.encoder_out = tf.concat([bi_encoder_state[0][-1][1],bi_encoder_state[1][-1][1]], -1)
        else:
            self.encoder_out = tf.concat([bi_encoder_state[0][-1],bi_encoder_state[1][-1]], -1)
        
    def add_stochastic_layer(self):
        # reparametrization trick
        self.z_mu = tf.layers.dense(self.encoder_out, self.latent_dim)
        self.z_lgs2 = tf.layers.dense(self.encoder_out, self.latent_dim)
        noise = tf.random_normal(tf.shape(self.z_lgs2))
        self.z = self.z_mu + tf.exp(0.5 * self.z_lgs2) * noise
    
    def add_decoder_hidden(self):
        hidden_state_list = []
        for i in range(self.n_layers * 2):
            if self.cell_type == 'gru':
                hidden_state_list.append(tf.layers.dense(self.z, self.rnn_size))
            else:
                hidden_state_list.append(tf.contrib.rnn.LSTMStateTuple(tf.layers.dense(self.z, self.rnn_size), tf.layers.dense(self.z, self.rnn_size))) 
        self.decoder_init_state = tuple(hidden_state_list)
        
    def processed_decoder_input(self):
        main = tf.strided_slice(self.Y, [0, 0], [self.batch_size, -1], [1, 1]) # remove last char
        decoder_input = tf.concat([tf.fill([self.batch_size, 1], self._y_go), main], 1)
        return decoder_input

    def add_decoder_for_training(self):
        self.decoder_cell = tf.contrib.rnn.MultiRNNCell([self.single_cell() for _ in range(2 * self.n_layers)])
        decoder_embedding = tf.get_variable('decoder_embedding', [len(self.dp.Y_w2id), self.decoder_embedding_dim],
                                             tf.float32, tf.random_uniform_initializer(-1.0, 1.0))
        emb = tf.nn.embedding_lookup(decoder_embedding, self.processed_decoder_input())
        inputs = tf.expand_dims(self.z, 1)
        inputs = tf.tile(inputs, [1, tf.shape(emb)[1], 1])
        inputs = tf.concat([emb, inputs],2) 
        training_helper = tf.contrib.seq2seq.TrainingHelper(
            inputs = inputs,
            sequence_length = self.Y_seq_len,
            time_major = False)
        training_decoder = tf.contrib.seq2seq.BasicDecoder(
            cell = self.decoder_cell,
            helper = training_helper,
            initial_state = self.decoder_init_state, #self.decoder_cell.zero_state(self.batch_size, tf.float32),
            output_layer = core_layers.Dense(len(self.dp.Y_w2id)))
        training_decoder_output, training_final_state, _ = tf.contrib.seq2seq.dynamic_decode(
            decoder = training_decoder,
            impute_finished = True,
            maximum_iterations = tf.reduce_max(self.Y_seq_len))
        self.training_logits = training_decoder_output.rnn_output
        self.init_prefix_state = training_final_state

    def add_decoder_for_inference(self):   
        decoder_embedding = tf.get_variable('decoder_embedding')
        self.beam_f = (lambda ids: tf.concat([tf.nn.embedding_lookup(decoder_embedding, ids), 
                                    tf.tile(tf.expand_dims(self.z, 1), 
                                            [1,int(tf.nn.embedding_lookup(decoder_embedding, ids).get_shape()[1]), 1]) if len(ids.get_shape()) !=1 
                                             else self.z], -1))

        predicting_decoder = tf.contrib.seq2seq.BeamSearchDecoder(
            cell = self.decoder_cell,
            embedding = self.beam_f, 
            start_tokens = tf.tile(tf.constant([self._y_go], dtype=tf.int32), [self.batch_size]),
            end_token = self._y_eos,
            initial_state = tf.contrib.seq2seq.tile_batch(self.decoder_init_state, self.beam_width),#self.decoder_cell.zero_state(self.batch_size * self.beam_width, tf.float32),
            beam_width = self.beam_width,
            output_layer = core_layers.Dense(len(self.dp.Y_w2id), _reuse=True),
            length_penalty_weight = self.beam_penalty)
        predicting_decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
            decoder = predicting_decoder,
            impute_finished = False,
            maximum_iterations = self.max_infer_length)
        self.predicting_ids = predicting_decoder_output.predicted_ids
        self.score = predicting_decoder_output.beam_search_decoder_output.scores
        
    def add_decoder_for_prefix_inference(self):   
        predicting_decoder = tf.contrib.seq2seq.BeamSearchDecoder(
            cell = self.decoder_cell,
            embedding = self.beam_f,
            start_tokens = tf.tile(tf.constant([self._y_go], dtype=tf.int32), [self.batch_size]),
            end_token = self._y_eos,
            initial_state = tf.contrib.seq2seq.tile_batch(self.init_prefix_state, self.beam_width),
            beam_width = self.beam_width,
            output_layer = core_layers.Dense(len(self.dp.Y_w2id), _reuse=True),
            length_penalty_weight = self.beam_penalty)
        
        self.prefix_go = tf.placeholder(tf.int32, [None])
        prefix_go_beam = tf.tile(tf.expand_dims(self.prefix_go, 1), [1, self.beam_width])
        prefix_emb = self.beam_f(prefix_go_beam)
        predicting_decoder._start_inputs = prefix_emb
        predicting_prefix_decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
            decoder = predicting_decoder,
            impute_finished = False,
            maximum_iterations = self.max_infer_length)
        self.predicting_prefix_ids = predicting_prefix_decoder_output.predicted_ids
        self.prefix_score = predicting_prefix_decoder_output.beam_search_decoder_output.scores

    def add_backward_path(self):
        masks = tf.sequence_mask(self.Y_seq_len, tf.reduce_max(self.Y_seq_len), dtype=tf.float32)
        self.reconstruct_loss = tf.contrib.seq2seq.sequence_loss(logits = self.training_logits,
                                                     targets = self.Y,
                                                     weights = masks)
        self.batch_reconstruct_loss = tf.contrib.seq2seq.sequence_loss(logits = self.training_logits,
                                                     targets = self.Y,
                                                     weights = masks,
                                                     average_across_batch=False)
        self.kl_loss = tf.reduce_mean(-0.5 * tf.reduce_sum(1 + self.z_lgs2 - tf.square(self.z_mu) - tf.exp(self.z_lgs2), 1))
        self.loss = self.reconstruct_loss + self.B * self.latent_weight * self.kl_loss
        
        params = tf.trainable_variables()
        gradients = tf.gradients(self.loss, params)
        clipped_gradients, _ = tf.clip_by_global_norm(gradients, self.grad_clip)
        self.learning_rate = tf.constant(self.lr)
        self.learning_rate = self.get_learning_rate_decay(self.decay_scheme)  # decay
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).apply_gradients(zip(clipped_gradients, params), global_step=self.global_step)

    def register_symbols(self):
        self._x_go = self.dp.X_w2id['<GO>']
        self._x_eos = self.dp.X_w2id['<EOS>']
        self._x_pad = self.dp.X_w2id['<PAD>']
        self._x_unk = self.dp.X_w2id['<UNK>']
        
        self._y_go = self.dp.Y_w2id['<GO>']
        self._y_eos = self.dp.Y_w2id['<EOS>']
        self._y_pad = self.dp.Y_w2id['<PAD>']
        self._y_unk = self.dp.Y_w2id['<UNK>']
    
    def infer(self, input_word):
        input_word = list(jieba.cut(input_word))
        if self.reverse:
            input_word = input_word[::-1]
        input_indices = [self.dp.X_w2id.get(char, self._x_unk) for char in input_word]
        out_indices = self.sess.run(self.predicting_ids, {
            self.X: [input_indices], self.X_seq_len: [len(input_indices)], self.output_keep_prob:1, self.input_keep_prob:1})
        outputs = []
        for idx in range(out_indices.shape[-1]):
            eos_id = self.dp.Y_w2id['<EOS>']
            ot = out_indices[0,:,idx]
            if eos_id in ot:
                ot = ot.tolist()
                ot = ot[:ot.index(eos_id)]
            if self.reverse:
                ot = ot[::-1]
            output_str = ''.join([self.dp.Y_id2w.get(i, u'&') for i in ot])
            outputs.append(output_str)
        return outputs
    
    def prefix_infer(self, input_word, prefix):
        input_word = list(jieba.cut(input_word))
        prefix = list(jieba.cut(prefix))
        input_indices_X = [self.dp.X_w2id.get(char, self._x_unk) for char in input_word]
        input_indices_Y = [self.dp.Y_w2id.get(char, self._y_unk) for char in prefix]
        
        prefix_go = []
        prefix_go.append(input_indices_Y[-1]) 
        out_indices, scores = self.sess.run([self.predicting_prefix_ids, self.prefix_score], {
            self.X: [input_indices_X], self.X_seq_len: [len(input_indices_X)], self.Y:[input_indices_Y], self.Y_seq_len:[len(input_indices_Y)],
            self.prefix_go: prefix_go, self.input_keep_prob:1, self.output_keep_prob:1})
        
        outputs = []
        for idx in range(out_indices.shape[-1]):
            eos_id = self.dp.Y_w2id['<EOS>']
            ot = out_indices[0,:,idx]
            if eos_id in ot:
                ot = ot.tolist()
                ot = ot[:ot.index(eos_id)]
                if self.reverse:
                    ot = ot[::-1]
            if self.reverse:
                output_str = ''.join([self.dp.Y_id2w.get(i, u'&') for i in ot]) + prefix
            else:
                output_str = prefix + ''.join([self.dp.Y_id2w.get(i, u'&') for i in ot])
            outputs.append(output_str)
        return outputs
    
    def xToz(self, input_word):
        input_word = list(jieba.cut(input_word))
        if self.reverse:
            input_word = input_word[::-1]
        input_indices = [self.dp.X_w2id.get(char, self._x_unk) for char in input_word]
        z = self.sess.run(self.z, {self.X: [input_indices], self.X_seq_len: [len(input_indices)], self.output_keep_prob:1, self.input_keep_prob:1})
        return z
    # end method
    
    def zTox(self, z):
        out_indices = self.sess.run(self.predicting_ids, {self.batch_size:z.shape[0],
            self.z:z, self.output_keep_prob:1, self.input_keep_prob:1})
        outputs = []
        for idx in range(out_indices.shape[-1]):
            eos_id = self.dp.Y_w2id['<EOS>']
            ot = out_indices[0,:,idx]
            if eos_id in ot:
                ot = ot.tolist()
                ot = ot[:ot.index(eos_id)]
            if self.reverse:
                ot = ot[::-1]
            output_str = ''.join([self.dp.Y_id2w.get(i, u'&') for i in ot])
            outputs.append(output_str)
        return outputs
    
    def generate(self, batch_size = 6):
        out_indices = self.sess.run(self.predicting_ids, { self.batch_size:batch_size,
            self.z:np.random.randn(batch_size, self.latent_dim), self.output_keep_prob:1, self.input_keep_prob:1})
        outputs = []
        for idx in range(out_indices.shape[0]):
            eos_id = self.dp.Y_w2id['<EOS>']
            ot = out_indices[idx,:,0]   # The 0th beam of each batch 
            if eos_id in ot:
                ot = ot.tolist()
                ot = ot[:ot.index(eos_id)]
            if self.reverse:
                ot = ot[::-1]
            output_str = ''.join([self.dp.Y_id2w.get(i, u'&') for i in ot])
            outputs.append(output_str)
        return outputs
    
    def restore(self, path):
        self.saver.restore(self.sess, path)
        print 'restore %s success' % path
        
    def get_learning_rate_decay(self, decay_scheme='luong234'):
        num_train_steps = self.dp.num_steps
        if decay_scheme == "luong10":
            start_decay_step = int(num_train_steps / 2)
            remain_steps = num_train_steps - start_decay_step
            decay_steps = int(remain_steps / 10)  # decay 10 times
            decay_factor = 0.5
        else:
            start_decay_step = int(num_train_steps * 2 / 3)
            remain_steps = num_train_steps - start_decay_step
            decay_steps = int(remain_steps / 4)  # decay 4 times
            decay_factor = 0.5
        return tf.cond(
            self.global_step < start_decay_step,
            lambda: self.learning_rate,
            lambda: tf.train.exponential_decay(
                self.learning_rate,
                (self.global_step - start_decay_step),
                decay_steps, decay_factor, staircase=True),
            name="learning_rate_decay_cond")
    
    def setup_summary(self):
        train_loss = tf.Variable(0.)
        tf.summary.scalar('Train_loss', train_loss) 
        train_KL_loss = tf.Variable(0.)
        tf.summary.scalar('Train_KL_loss', train_KL_loss)
        train_r_loss = tf.Variable(0.)
        tf.summary.scalar('Train_R_loss', train_r_loss)
        test_loss = tf.Variable(0.)
        tf.summary.scalar('Test_loss', test_loss) 
        test_KL_loss = tf.Variable(0.)
        tf.summary.scalar('Test_KL_loss', test_KL_loss)
        test_r_loss = tf.Variable(0.)
        tf.summary.scalar('Test_R_loss', test_r_loss)
        beta = tf.Variable(0.)
        tf.summary.scalar('Beta', beta)
        tf.summary.scalar('lr_rate', self.learning_rate)
        tf.summary.histogram("z_mu", self.z_mu)
        tf.summary.histogram("z_ls2", self.z_lgs2)
        tf.summary.histogram("z", self.z)
        
        summary_vars = [train_loss, train_KL_loss, train_r_loss, test_loss, test_KL_loss, test_r_loss, beta]
        summary_placeholders = [tf.placeholder(tf.float32) for _ in xrange(len(summary_vars))]
        update_ops = [summary_vars[i].assign(summary_placeholders[i]) for i in xrange(len(summary_vars))]
        summary_op = tf.summary.merge_all()
        return summary_placeholders, update_ops, summary_op

# %%
class VRAE_DP:
    def __init__(self, X_indices, Y_indices, X_w2id, Y_w2id, BATCH_SIZE, n_epoch):
        assert len(X_indices) == len(Y_indices)
        num_test = int(len(X_indices) * 0.1)
        self.n_epoch = n_epoch
        self.X_train = np.array(X_indices[num_test:])
        self.Y_train = np.array(Y_indices[num_test:])
        self.X_test = np.array(X_indices[:num_test])
        self.Y_test = np.array(Y_indices[:num_test])
        self.num_batch = int(len(self.X_train) / BATCH_SIZE)
        self.num_steps = self.num_batch * self.n_epoch
        self.batch_size = BATCH_SIZE
        self.X_w2id = X_w2id
        self.X_id2w = dict(zip(X_w2id.values(), X_w2id.keys()))
        self.Y_w2id = Y_w2id
        self.Y_id2w = dict(zip(Y_w2id.values(), Y_w2id.keys()))
        self._x_pad = self.X_w2id['<PAD>']
        self._y_pad = self.Y_w2id['<PAD>']
        print 'Train_data: %d | Test_data: %d | Batch_size: %d | Num_batch: %d | X_vocab_size: %d | Y_vocab_size: %d' % (len(self.X_train), len(self.X_test), BATCH_SIZE, self.num_batch, len(self.X_w2id), len(self.Y_w2id))
        
    def next_batch(self, X, Y):
        r = np.random.permutation(len(X))
        X = X[r]
        Y = Y[r]
        for i in range(0, len(X) - len(X) % self.batch_size, self.batch_size):
            X_batch = X[i : i + self.batch_size]
            Y_batch = Y[i : i + self.batch_size]
            padded_X_batch, X_batch_lens = self.pad_sentence_batch(X_batch, self._x_pad)
            padded_Y_batch, Y_batch_lens = self.pad_sentence_batch(Y_batch, self._y_pad)
            yield (np.array(padded_X_batch),
                   np.array(padded_Y_batch),
                   X_batch_lens,
                   Y_batch_lens)
    
    def sample_test_batch(self):
        padded_X_batch, X_batch_lens = self.pad_sentence_batch(self.X_test[: self.batch_size], self._x_pad)
        padded_Y_batch, Y_batch_lens = self.pad_sentence_batch(self.Y_test[: self.batch_size], self._y_pad)
        return np.array(padded_X_batch), np.array(padded_Y_batch), X_batch_lens, Y_batch_lens
        
    def pad_sentence_batch(self, sentence_batch, pad_int):
        padded_seqs = []
        seq_lens = []
        max_sentence_len = max([len(sentence) for sentence in sentence_batch])
        for sentence in sentence_batch:
            padded_seqs.append(sentence + [pad_int] * (max_sentence_len - len(sentence)))
            seq_lens.append(len(sentence))
        return padded_seqs, seq_lens

# %%
import scipy.interpolate as si
from scipy import interpolate


def BetaGenerator(epoches, beta_decay_period, beta_decay_offset):
    points = [[0,0], [0, beta_decay_offset],[0, beta_decay_offset + 0.33 * beta_decay_period], [1, beta_decay_offset + 0.66*beta_decay_period],[1, beta_decay_offset + beta_decay_period], [1, epoches] ];
    points = np.array(points)
    x = points[:,0]
    y = points[:,1]
    t = range(len(points))
    ipl_t = np.linspace(0.0, len(points) - 1, 100)
    x_tup = si.splrep(t, x, k=3)
    y_tup = si.splrep(t, y, k=3)
    x_list = list(x_tup)
    xl = x.tolist()
    x_list[1] = xl + [0.0, 0.0, 0.0, 0.0]
    y_list = list(y_tup)
    yl = y.tolist()
    y_list[1] = yl + [0.0, 0.0, 0.0, 0.0]
    x_i = si.splev(ipl_t, x_list)
    y_i = si.splev(ipl_t, y_list)
    return interpolate.interp1d(y_i, x_i)

class VRAE_util:
    def __init__(self, dp, model, display_freq=3):
        self.display_freq = display_freq
        self.dp = dp
        self.model = model
        self.summary_cnt = 0
        self.betaG = BetaGenerator(self.dp.n_epoch*self.dp.num_batch, self.model.beta_decay_period*self.dp.num_batch, self.model.beta_decay_offset*self.dp.num_batch)
        
    def train(self, epoch):
        avg_loss = 0.0
        avg_r_loss = 0.0
        avg_kl_loss = 0.0
        tic = time.time()
        X_test_batch, Y_test_batch, X_test_batch_lens, Y_test_batch_lens = self.dp.sample_test_batch()
        for local_step, (X_train_batch, Y_train_batch, X_train_batch_lens, Y_train_batch_lens) in enumerate(
            self.dp.next_batch(self.dp.X_train, self.dp.Y_train)):
            beta = 0.001 + self.betaG(self.model.step) # add small value to avoid points to scatter
            self.model.step, _, loss, r_loss, kl_loss = self.model.sess.run([self.model.global_step, self.model.train_op, 
                                                            self.model.loss, self.model.reconstruct_loss, self.model.kl_loss], 
                                          {self.model.X: X_train_batch,
                                           self.model.Y: Y_train_batch,
                                           self.model.X_seq_len: X_train_batch_lens,
                                           self.model.Y_seq_len: Y_train_batch_lens,
                                           self.model.output_keep_prob:self.model._output_keep_prob,
                                           self.model.input_keep_prob:self.model._input_keep_prob,
                                          self.model.B:beta})
            avg_loss += loss
            avg_r_loss += r_loss
            avg_kl_loss += kl_loss
            # summary
            if local_step % 10 == 0:
                self.summary_cnt += 1
                val_loss, val_r_loss, val_kl_loss = self.model.sess.run([self.model.loss, self.model.reconstruct_loss, self.model.kl_loss], 
                                               {self.model.X: X_test_batch,
                                                     self.model.Y: Y_test_batch,
                                                     self.model.X_seq_len: X_test_batch_lens,
                                                     self.model.Y_seq_len: Y_test_batch_lens,
                                                     self.model.output_keep_prob:1,
                                                     self.model.input_keep_prob:1,
                                                     self.model.B:beta})
                stats = [avg_loss/(local_step+1), avg_kl_loss/(local_step+1), avg_r_loss/(local_step+1),
                         val_loss, val_kl_loss, val_r_loss, beta]
                for i in xrange(len(stats)):
                    self.model.sess.run(self.model.update_ops[i], feed_dict={
                        self.model.summary_placeholders[i]: float(stats[i])
                    })
                summary_str = self.model.sess.run(self.model.summary_op, {
                    self.model.X: X_test_batch, 
                    self.model.X_seq_len: X_test_batch_lens,
                    self.model.output_keep_prob:1,
                    self.model.input_keep_prob:1})
                self.summary_writer.add_summary(summary_str, self.summary_cnt)
                
            if local_step % (self.dp.num_batch / self.display_freq) == 0:
                val_loss, val_r_loss, val_kl_loss = self.model.sess.run([self.model.loss, self.model.reconstruct_loss, self.model.kl_loss], 
                                               {self.model.X: X_test_batch,
                                                     self.model.Y: Y_test_batch,
                                                     self.model.X_seq_len: X_test_batch_lens,
                                                     self.model.Y_seq_len: Y_test_batch_lens,
                                                     self.model.output_keep_prob:1,
                                                     self.model.input_keep_prob:1,
                                                     self.model.B:beta})
                print "Epoch %d/%d | Batch %d/%d | Train_loss: %.3f = %.3f + %.3f | Test_loss: %.3f = %.3f + %.3f | Time_cost:%.3f" % (epoch, self.n_epoch, local_step, self.dp.num_batch, 
                                                                                                                                       avg_loss / (local_step + 1),
                                                                                                                                       avg_r_loss / (local_step + 1),
                                                                                                                                       avg_kl_loss / (local_step + 1),
                                                                                                                                       val_loss, val_r_loss, val_kl_loss, time.time()-tic)
                self.cal()
                tic = time.time()
        return avg_loss / self.dp.num_batch, avg_r_loss / self.dp.num_batch, avg_kl_loss / self.dp.num_batch
    
    def test(self):
        avg_loss = 0.0
        avg_r_loss = 0.0
        avg_kl_loss = 0.0
        beta = 0.001 + self.betaG(self.model.step) # add small value to avoid points to scatter
        for local_step, (X_test_batch, Y_test_batch, X_test_batch_lens, Y_test_batch_lens) in enumerate(
            self.dp.next_batch(self.dp.X_test, self.dp.Y_test)):
            val_loss, val_r_loss, val_kl_loss = self.model.sess.run([self.model.loss, self.model.reconstruct_loss, self.model.kl_loss], 
                                                                   {self.model.X: X_test_batch,
                                                                         self.model.Y: Y_test_batch,
                                                                         self.model.X_seq_len: X_test_batch_lens,
                                                                         self.model.Y_seq_len: Y_test_batch_lens,
                                                                         self.model.output_keep_prob:1,
                                                                         self.model.input_keep_prob:1,
                                                                         self.model.B:beta})
            avg_loss += val_loss
            avg_r_loss += val_r_loss
            avg_kl_loss += val_kl_loss
        return avg_loss / (local_step + 1), avg_r_loss / (local_step + 1), avg_kl_loss / (local_step + 1)
    
    def fit(self, train_dir, is_bleu):
        self.n_epoch = self.dp.n_epoch
        test_loss_list = []
        train_loss_list = []
        test_r_loss_list = []
        train_r_loss_list = []
        test_kl_loss_list = []
        train_kl_loss_list = []
        time_cost_list = []
        bleu_list = []
        timestamp = str(int(time.time()))
        out_dir = os.path.abspath(os.path.join(train_dir, "runs", timestamp))
        if not os.path.exists(out_dir):
            os.makedirs(out_dir)
        print "Writing to %s" % out_dir
        checkpoint_prefix = os.path.join(out_dir, "model")
        self.summary_writer = tf.summary.FileWriter(os.path.join(out_dir, 'Summary'), self.model.sess.graph)
        for epoch in range(1, self.n_epoch+1):
            tic = time.time()
            train_loss, train_r_loss, train_kl_loss = self.train(epoch)
            train_loss_list.append(train_loss)
            train_r_loss_list.append(train_r_loss)
            train_kl_loss_list.append(train_kl_loss)
            
            test_loss, test_r_loss, test_kl_loss = self.test()
            test_loss_list.append(test_loss)
            test_r_loss_list.append(test_r_loss)
            test_kl_loss_list.append(test_kl_loss)
            toc = time.time()
            time_cost_list.append((toc - tic))
            if is_bleu:
                bleu = self.test_bleu()
                bleu_list.append(bleu)
                print "Epoch %d/%d | Train_loss: %.3f = %.3f + %.3f | Test_loss: %.3f = %.3f + %.3f | Bleu: %.3f" % (epoch, self.n_epoch, train_loss, train_r_loss, train_kl_loss, test_loss, test_r_loss, test_kl_loss, bleu)
            else:
                bleu = 0.0
                print "Epoch %d/%d | Train_loss: %.3f = %.3f + %.3f | Test_loss: %.3f = %.3f + %.3f" % (epoch, self.n_epoch, train_loss, train_r_loss, train_kl_loss, test_loss, test_r_loss, test_kl_loss)
            if self.model.is_save:
                cPickle.dump((train_loss_list, train_r_loss_list, train_kl_loss_list, test_loss_list, test_r_loss_list, test_kl_loss_list, time_cost_list, bleu_list), open(os.path.join(out_dir,"res.pkl"),'wb'))
                path = self.model.saver.save(self.model.sess, checkpoint_prefix, global_step=epoch)
                print "Saved model checkpoint to %s" % path
    
    def show(self, sent, id2w):
        return "".join([id2w.get(idx, u'&') for idx in sent])
    
    def cal(self, n_example=5):
        train_n_example = int(n_example / 2)
        test_n_example = n_example - train_n_example
        for _ in range(test_n_example):
            example = self.show(self.dp.X_test[_], self.dp.X_id2w)
            y = self.show(self.dp.Y_test[_], self.dp.Y_id2w)
            o = self.model.infer(example)[0]
            print 'Test_Input: %s | Output: %s | GroundTruth: %s' % (example, o, y)
        for _ in range(train_n_example):
            example = self.show(self.dp.X_train[_], self.dp.X_id2w)
            y = self.show(self.dp.Y_train[_], self.dp.Y_id2w)
            o = self.model.infer(example)[0]
            print 'Train_Input: %s | Output: %s | GroundTruth: %s' % (example, o, y) 
        o = self.model.generate()
        print 'generate:'
        for oo in o:
            print '【',oo,'】'
        print ""
        
    def test_bleu(self, N=300, gram=4):
        all_score = []
        for i in range(N):
            input_indices = self.show(self.dp.X_test[i], self.dp.X_id2w)
            o = self.model.infer(input_indices)[0]
            refer4bleu = [[' '.join([self.dp.Y_id2w.get(w, u'&') for w in self.dp.Y_test[i]])]]
            candi = [' '.join(w for w in o)]
            score = BLEU(candi, refer4bleu, gram=gram)
            all_score.append(score)
        return np.mean(all_score)
    
    def show_res(self, path):
        res = cPickle.load(open(path))
        plt.figure(1)
        plt.title('The train results') 
        l1, = plt.plot(res[0], 'g')
        l2, = plt.plot(res[1], 'r')
        l3, = plt.plot(res[2], 'b')
        plt.legend(handles = [l1, l2, l3], labels = ["Train_loss","Train_r_loss","Train_kl_loss"], loc = 'best')
        plt.show()
        
        plt.figure(1)
        plt.title('The test results') 
        l4, = plt.plot(res[3], 'g')
        l5, = plt.plot(res[4], 'r')
        l6, = plt.plot(res[5], 'r')
        l7, = plt.plot(res[-1], 'b')
        plt.legend(handles = [l4, l5, l6, l7], labels = ["Test_loss","Test_r_loss","Test_kl_loss","BLEU"], loc = 'best')
        plt.show()
        
    def test_all(self, path, epoch_range, is_bleu=True):
        val_loss_list = []
        bleu_list = []
        for i in range(epoch_range[0], epoch_range[-1]):
            self.model.restore(path + str(i))
            val_loss = self.test()
            val_loss_list.append(val_loss)
            if is_bleu:
                bleu_score = self.test_bleu()
                bleu_list.append(bleu_score)
        plt.figure(1)
        plt.title('The results') 
        l1, = plt.plot(val_loss_list,'r')
        l2, = plt.plot(bleu_list,'b')
        plt.legend(handles = [l1, l2], labels = ["Test_loss","BLEU"], loc = 'best')
        plt.show()

# %%
import cPickle
top, mid, down = cPickle.load(open('JD/JD_top_mid_down_indices.pkl'))
#data = cPickle.load(open('JD/JD_small_indices.pkl'))

w2id, id2w = cPickle.load(open('JD/JD_w2id_id2w.pkl'))
train_dir = 'char_vae_model/'
print len(w2id)
#print len(top), len(mid), len(down)

data = top + mid + down
data_X = [o[:-1] for o in data]
# Out:
# 9191

# %%
BATCH_SIZE = 256
NUM_EPOCH = 15

dp = VRAE_DP(data_X, data, w2id, w2id, BATCH_SIZE, n_epoch=NUM_EPOCH)
g = tf.Graph() 
sess = tf.Session(graph=g) 
with sess.as_default():
    with sess.graph.as_default():
        model = VRAE(
            dp = dp,
            rnn_size = 1024,
            latent_dim = 16,
            n_layers = 1,
            encoder_embedding_dim = 512,
            decoder_embedding_dim = 512,
            cell_type='gru',
            max_infer_length=31,
            residual=False,
            is_save=True,
            beam_width=5,
            sess= sess
        )
        
util = VRAE_util(dp=dp, model=model)
#util.fit(train_dir=train_dir, is_bleu=False)
# Out:
# Train_data: 526028 | Test_data: 58447 | Batch_size: 256 | Num_batch: 2054 | X_vocab_size: 9191 | Y_vocab_size: 9191

# %% [markdown]
# # 测试

# %%
import random

candi = []
candi += random.sample(top, 10)
candi += random.sample(down, 10)
candi += random.sample(mid, 10)

candi = ["".join([dp.X_id2w[idx] for idx in c[:-1]]) for c in candi]
for c in candi:
    print c
# Out:
# 不错很合适
# 质量，不错，很美美哒拉风。 第二次购买了，发货很快，质量有保障
# 商品本身还行，就是有点卡头发
# 感觉还可以，不错，真心不错。
# 送给情人的 非常满意 谢谢热情的卖家
# 老婆很喜欢，很满意。
# 太好了，不错很喜欢
# 东西非常好，快递很快，昨天下的单今天就到了，谢谢了
# 下次还来，老板记得给打个折哦
# 卡子挺漂亮的，就是太沉了
# 失望透了
# 大家不要买，质量又不好，感觉像**的地摊货
# 速速慢啊 还没有送到
# 没得说！
# 快递太慢，女朋友不满意，<UNK>早日关门。
# 快递好慢！ 必须差评差评差评 差评差评差评
# 感觉差，边上好多<UNK>，稍微有点刮手，而且表面漆也不好
# 质量不好，根本夹不住头发，
# 垃圾东西，没想到在京东上也有垃圾货骗人
# 一点都不满意！特别是绳子！没用几天就断了！貔貅也成玻璃渣了！碎的！
# 女款和网上图片不一样，字也刻歪了，有点长
# 质量不怎么样 总体感觉还行吧 毕竟价格在那里
# 不实用，用不到。
# 实物与网上照片有差异，不太理想，真实点应该可以持久
# 买回来第二天就断了。换了送的皮筋。第3天又断了。。看来不适合我
# 有点重，物流有点慢，快递大哥辛苦了
# 怎么<UNK>不了，怎么扣的
# 好小好小呀，和想象的出入太大了
# 不好看不好看
# 还行挺好看的

# %%
def linear_transfer(good, bad, candi_list):
    z_good = model.xToz(good)
    z_bad = model.xToz(bad)
    o_good = model.zTox(z_good)[0]
    o_bad = model.zTox(z_bad)[0]
    z = z_bad - z_good
    print 'good:%s | bad:%s' % (o_good, o_bad)
    for c in candi_list:
        z_c = model.xToz(c)
        o_r = model.zTox(z_c)[0]
        o_tb = model.zTox(z_c + z)[0]
        o_tg = model.zTox(z_c - z)[0]
        print "-----------------------------------------------------------"
        print "origin: %s | reconstruct: %s" % (c, o_r)
        print "transfer_g: %s | transfer_b: %s " % (o_tg, o_tb)
        
def interpolations(A, B, n=10):
    z1 = model.xToz(A)
    z2 = model.xToz(B)
    z_list = [z1+((z2-z1)/n)*i for i in range(1,n+1)]
    print "-----------------------------------------------------------"
    print A
    for z in z_list:
        print model.zTox(z)[0]
    print B

# %%
for i in range(6,16):
    print 'epoch:%d==================================================' % i
    model.restore('/root/VAE/char_vae_model/runs/1513220661/model-%d' % i)
    interpolations(u'不实用，用不上', u'很不错，做工精细，物有所值，值得购买，',n=10)
    interpolations(u'垃圾，发货慢的要死', u'很不错，做工精细，物有所值，值得购买，',n=10)
    linear_transfer(u'我很喜欢', u'差评', candi)
    print '==========================================================='
# Out:
# epoch:6==================================================
# INFO:tensorflow:Restoring parameters from /root/VAE/char_vae_model/runs/1513220661/model-6
# restore /root/VAE/char_vae_model/runs/1513220661/model-6 success
# -----------------------------------------------------------
# 不实用，用不上
# 不实用，<UNK>
# 不实用，很漂亮啊
# 说真的，不好看。
# 不赖，很好看就行！
# 挺美的，很漂亮，很不喜欢
# 价格便宜，很好看，值得购买！
# 很好看，发货快，不错！！
# 很好，很漂亮，价格合适！！
# 很不错，价格便宜，做工精细，满意！
# 很不错，价格便宜，做工精细，物美价廉！
# 很不错，做工精细，物有所值，值得购买，
# -----------------------------------------------------------
# 垃圾，发货慢的要死
# 垃圾，发货慢的要死，
# 差评，质量好差，和卖家的
# 好评，质量好差，和<UNK>
# 货真价实，质量信得过，和卖家一样
# 货真价实，质量好，发货很快。
# 货真价实，质量不错，特别满意。
# 很漂亮，质量很好，价格低，送货快。
# 很漂亮，质量很好，货真价实，值得推荐！
# 很不错，价格便宜，做工精细，物美价廉！
# 很不错，价格便宜，做工精细，物美价廉！
# 很不错，做工精细，物有所值，值得购买，
# good:我很喜欢 | bad:差评
# -----------------------------------------------------------
# origin: 不错很合适 | reconstruct: 不错很合适
# transfer_g: 不错很好看很不错 | transfer_b: 比较满意，比较满意
# -----------------------------------------------------------
# origin: 质量，不错，很美美哒拉风。 第二次购买了，发货很快，质量有保障 | reconstruct: 质量不错，做工精细，很喜欢，下次还来买，么么哒，赞一个。
# transfer_g: 戒指不错，很喜欢啊，质量很好很漂亮，很喜欢呢还送了小礼物呢 | transfer_b: 一般般，质量，，，做工精细，性价比高！！！！！5分！5分！
# -----------------------------------------------------------
# origin: 商品本身还行，就是有点卡头发 | reconstruct: 戒指还行，但包装太简陋。
# transfer_g: 这个看起来很好小小珠子也很不错 | transfer_b: 做工还凑合，一分钱一分货，烂烂烂烂差评。
# -----------------------------------------------------------
# origin: 感觉还可以，不错，真心不错。 | reconstruct: 感觉还不错，错，很不错！
# transfer_g: 这个感觉不错很好看，感觉很不错啊 | transfer_b: 还凑合，价格，小贵！！！！
# -----------------------------------------------------------
# origin: 送给情人的 非常满意 谢谢热情的卖家 | reconstruct: 一次愉快的购物 满意的购物 朋友很喜欢
# transfer_g: 我老公很喜欢的也非常不错的说 | transfer_b: 愉快的，必须好评，物流必须的到位
# -----------------------------------------------------------
# origin: 老婆很喜欢，很满意。 | reconstruct: 老婆很喜欢，很满意。
# transfer_g: 我老婆很很很喜欢很不错，好看 | transfer_b: 收到，很满意！！！
# -----------------------------------------------------------
# origin: 太好了，不错很喜欢 | reconstruct: 太好了，不错很喜欢
# transfer_g: 我很不错，好喜欢 | transfer_b: ，，！！！
# -----------------------------------------------------------
# origin: 东西非常好，快递很快，昨天下的单今天就到了，谢谢了 | reconstruct: 东西非常好，快递速度很快，昨天买的今天就到了，必须好评
# transfer_g: 东西真的很好我好喜欢，东西是正品哦，下次还会在来的 真心不错 | transfer_b: 快递差，差，垃圾！垃圾！发货速度快，以后还会来的不要不要的
# -----------------------------------------------------------
# origin: 下次还来，老板记得给打个折哦 | reconstruct: 老板服务周到，下次还来你可要给优惠了
# transfer_g: 第一次买我很不错下次有需要也来买 | transfer_b: 太慢，必须5分，5分5分！
# -----------------------------------------------------------
# origin: 卡子挺漂亮的，就是太沉了 | reconstruct: 卡子挺漂亮的，就是太沉了
# transfer_g: 感觉蛮好的很喜欢戴 | transfer_b: 马马虎虎的，结实！有待！
# -----------------------------------------------------------
# origin: 失望透了 | reconstruct: 失望透了
# transfer_g: 我姑娘好很喜欢 | transfer_b: 差评！包装差
# -----------------------------------------------------------
# origin: 大家不要买，质量又不好，感觉像**的地摊货 | reconstruct: 像***，****，太好了，以后会经常买
# transfer_g: 我觉得好漂亮啊带着恨好，这个价格又好，很好用 | transfer_b: 差，****，差到极点，差，懒得退！差！烂货
# -----------------------------------------------------------
# origin: 速速慢啊 还没有送到 | reconstruct: 没有什么问题 还送了东西
# transfer_g: 我觉得还很好还真的还好 | transfer_b: 差，快递速度太慢，一般般
# -----------------------------------------------------------
# origin: 没得说！ | reconstruct: 没得说！
# transfer_g: 我很喜欢不错 | transfer_b: 差评！！
# -----------------------------------------------------------
# origin: 快递太慢，女朋友不满意，<UNK>早日关门。 | reconstruct: 快递太慢，很给力，就是不知道为什么是正品。
# transfer_g: 这个我很满意，我觉得很漂亮我也很喜欢。下次还来 | transfer_b: 物流太慢，差评，差评。严重差评差评差评@@
# -----------------------------------------------------------
# origin: 快递好慢！ 必须差评差评差评 差评差评差评 | reconstruct: 快递太慢！ 必须差评差评 必须差评的差评
# transfer_g: 东西到了也很给力，我是你懂的 | transfer_b: 辣鸡！差评！差评差评差评差评差评差评 差评差评差评差评差评差评差评差评
# -----------------------------------------------------------
# origin: 感觉差，边上好多<UNK>，稍微有点刮手，而且表面漆也不好 | reconstruct: 绳子有点不好，毕竟价钱在那里，<UNK>着也不好，建议大家不要买了
# transfer_g: 这个<UNK>真的很好啊，戴在手上也很好看，就是感觉有点小一点<UNK> | transfer_b: 差差差，差差差，差差差，根本还不行，根本就断开严重差评。
# -----------------------------------------------------------
# origin: 质量不好，根本夹不住头发， | reconstruct: 质量不好，根本夹不住头发，
# transfer_g: 感觉很好用 珠子都掉了 | transfer_b: 差差差，差，差差容易坏！差评
# -----------------------------------------------------------
# origin: 垃圾东西，没想到在京东上也有垃圾货骗人 | reconstruct: 垃圾东西，在京东上也没必要联系京东
# transfer_g: 和我在街买东西也很好，我也没啥说 | transfer_b: 垃圾，垃圾垃圾垃圾，物流速度就一个字差，辣鸡辣鸡
# -----------------------------------------------------------
# origin: 一点都不满意！特别是绳子！没用几天就断了！貔貅也成玻璃渣了！碎的！ | reconstruct: 一点都不满意！一点都不好看！花都掉漆了！而且还有一个小盒的东西，太不值了
# transfer_g: 我个人非常喜欢颜色都不是很好不知道会不会掉颜色？我也是醉了醉了，总之非常好。 | transfer_b: 不严重差评！差！严重差！严重差评！严重差评！严重差评！严重差评！严重差评差评差评差评差评差评差评差评差评
# -----------------------------------------------------------
# origin: 女款和网上图片不一样，字也刻歪了，有点长 | reconstruct: 照片和实物不符合，但是那个圈太大了，而且也看不清
# transfer_g: 我觉得链子和颜色都觉得很好看呢 戴起来感觉很好看 很喜欢 | transfer_b: 严重差评，与实物严重不符，链子也不退！差评！
# -----------------------------------------------------------
# origin: 质量不怎么样 总体感觉还行吧 毕竟价格在那里 | reconstruct: 还行吧 质量一般毕竟价格在那 就是有点不
# transfer_g: 感觉都不错 不过感觉比我想象中要质量也不错 | transfer_b: 一般般！质量差，价格也不值10块钱吧
# -----------------------------------------------------------
# origin: 不实用，用不到。 | reconstruct: 不实用，不会用。
# transfer_g: 女儿说很好看，感觉<UNK> | transfer_b: 不太好，一分钱一分货，差评一个。
# -----------------------------------------------------------
# origin: 实物与网上照片有差异，不太理想，真实点应该可以持久 | reconstruct: 实物与图片相差很大，毕竟是赠送品，还算可以吧。
# transfer_g: 这手链和图片上看起来很好看，感觉不是很不错还有小礼品 | transfer_b: 包装不行，与实物有差距，一分钱一分货，凑合凑合吧！差评！
# -----------------------------------------------------------
# origin: 买回来第二天就断了。换了送的皮筋。第3天又断了。。看来不适合我 | reconstruct: 刚买回来就断了。0元买的太麻烦了。。。后来发现不小心丢了。后来还担心丢了
# transfer_g: 这款我已经戴了很久了。买了自己带着感觉挺好的。我很喜欢下次再买你们家的。 | transfer_b: 差差差差差评！差评！坏的！！！！！再两天就断了！差评！差评差评差评差评差评差评差评差评差评差评差评
# -----------------------------------------------------------
# origin: 有点重，物流有点慢，快递大哥辛苦了 | reconstruct: 有点失望，物流有点慢，其馀可以！
# transfer_g: 我觉得很不错，不过实物和图片有点差别 | transfer_b: 差评，一般般。包装一般般，送货速度太慢
# -----------------------------------------------------------
# origin: 怎么<UNK>不了，怎么扣的 | reconstruct: 怎么<UNK><UNK><UNK>就<UNK>的，有点锈迹
# transfer_g: 我<UNK>我<UNK><UNK><UNK>不过不是很好看用 | transfer_b: 差评差评，根本还没有坏。差评。
# -----------------------------------------------------------
# origin: 好小好小呀，和想象的出入太大了 | reconstruct: 没想像中好，只是我选的有点大了
# transfer_g: 我觉得比我想象的好小 带着很不错 | transfer_b: 差，没两天断的，差评吧！！
# -----------------------------------------------------------
# origin: 不好看不好看 | reconstruct: 不好看不好看
# transfer_g: 我好看好看好看很好看 | transfer_b: 不结实，不怎样
# -----------------------------------------------------------
# origin: 还行挺好看的 | reconstruct: 样子挺好看的
# transfer_g: 感觉很好看蛮好看的 | transfer_b: 一般般吧，比较满意
# ===========================================================
# epoch:7==================================================
# INFO:tensorflow:Restoring parameters from /root/VAE/char_vae_model/runs/1513220661/model-7
# restore /root/VAE/char_vae_model/runs/1513220661/model-7 success
# -----------------------------------------------------------
# 不实用，用不上
# 不好看，努力<UNK>
# 不，干什么用。
# 挺美的，嗯，我喜欢
# 挺美的，嗯，我喜欢
# 很好看，值这个，！
# 价格便宜，很好看，值得购买！
# 很好，很帅，值得拥有！
# 很不错，价格合理，超满意！
# 很不错，价格便宜，做工精细，值得购买
# 很不错，做工精细，物有所值，值得购买，
# 很不错，做工精细，物有所值，值得购买，
# -----------------------------------------------------------
# 垃圾，发货慢的要死
# 垃圾，发货慢的要死
# 差评，质量和描述一样。
# 差评，质量好。绝对
# 货真价实，质量好，给差评
# 货真价实，质量好，发货迅速。
# 货真价实，质量好，女朋友很满意。
# 很漂亮，质量很好，货真价实，强烈推荐！
# 很漂亮，质量很好，货真价实，值得购买
# 很不错，做工精细，物有所值，值得购买
# 很不错，做工精细，物有所值，值得购买，
# 很不错，做工精细，物有所值，值得购买，
# good:我很喜欢 | bad:差评
# -----------------------------------------------------------
# origin: 不错很合适 | reconstruct: 不错很合适
# transfer_g: 很不错我很喜欢 | transfer_b: 满意过得去
# -----------------------------------------------------------
# origin: 质量，不错，很美美哒拉风。 第二次购买了，发货很快，质量有保障 | reconstruct: 质量好，很漂亮，做工很精细，赞一个！还送了小礼物，值得拥有！
# transfer_g: 东西不错，很喜欢，戴了很久哦，而且卖家态度很好，下次还来。 | transfer_b: 可以，做工精细，物超所值，质量好，性价比高！5分好评！5分！
# -----------------------------------------------------------
# origin: 商品本身还行，就是有点卡头发 | reconstruct: 产品还算可以，就是珠子有点大
# transfer_g: 这个东西很不错戴在手上有点小，不好看 | transfer_b: 做工还凑合，与塑料不符
# -----------------------------------------------------------
# origin: 感觉还可以，不错，真心不错。 | reconstruct: 感觉还不错，很值，很不错。
# transfer_g: 东西感觉很不错，带着很不错，不错。 | transfer_b: 总体，还行，价格小贵！！
# -----------------------------------------------------------
# origin: 送给情人的 非常满意 谢谢热情的卖家 | reconstruct: 送给姐姐的 非常满意 下次还会光顾的
# transfer_g: 女朋友说很喜欢的，卖家服务态度也非常好的 | transfer_b: 物超所值的，发货也快，愉快的购物
# -----------------------------------------------------------
# origin: 老婆很喜欢，很满意。 | reconstruct: 老婆很喜欢，很满意。
# transfer_g: 我老婆很喜欢很好看，很喜欢。 | transfer_b: 很赞！很满意，比较满意
# -----------------------------------------------------------
# origin: 太好了，不错很喜欢 | reconstruct: 物美价廉，真的很喜欢
# transfer_g: 很喜欢啊，不错不错 | transfer_b: 漂亮，速度快！
# -----------------------------------------------------------
# origin: 东西非常好，快递很快，昨天下的单今天就到了，谢谢了 | reconstruct: 东西非常好，快递速度很快，昨天买的今天就到了，谢谢卖家
# transfer_g: 东西真的很好，我喜欢这条东西，下次还会再来买的，真心喜欢 | transfer_b: 质量差，发货快，京东的服务态度差，京东物流垃圾京东！
# -----------------------------------------------------------
# origin: 下次还来，老板记得给打个折哦 | reconstruct: 下次还来，卖家还打电话给你啦
# transfer_g: 给我女儿买哦，他很喜欢下次还来京东 | transfer_b: 差，发货速度必须5，5分好评
# -----------------------------------------------------------
# origin: 卡子挺漂亮的，就是太沉了 | reconstruct: 卡子挺漂亮的，就是太沉了
# transfer_g: 看着很好看买的喜欢，刚刚好 | transfer_b: 差的，做工粗糙！
# -----------------------------------------------------------
# origin: 失望透了 | reconstruct: 失望透了
# transfer_g: 我看了很喜欢 | transfer_b: 垃圾差评！
# -----------------------------------------------------------
# origin: 大家不要买，质量又不好，感觉像**的地摊货 | reconstruct: 一点都不好，******，买了，物流也挺快吧！
# transfer_g: 感觉好同事都说好看，买了两个，都觉得还可以吧！ | transfer_b: 差差，差差差，****，质量差的假货
# -----------------------------------------------------------
# origin: 速速慢啊 还没有送到 | reconstruct: 没有什么问题 还送了东西
# transfer_g: 我觉得还很好呢……&hellip; | transfer_b: 差，快递速度差差差
# -----------------------------------------------------------
# origin: 没得说！ | reconstruct: good！
# transfer_g: 我很喜欢！ | transfer_b: 差！！
# -----------------------------------------------------------
# origin: 快递太慢，女朋友不满意，<UNK>早日关门。 | reconstruct: 快递太慢，商品很给力，不知道我会不会掉色。
# transfer_g: 这个我很喜欢，我也很满意，下次我还没去。？？ | transfer_b: 不行，发货太慢，差评差评差评差评差评差评。
# -----------------------------------------------------------
# origin: 快递好慢！ 必须差评差评差评 差评差评差评 | reconstruct: 快递太慢，太慢了差评差评~~~~
# transfer_g: 东西给力 我也不喜欢？？？？？？？ | transfer_b: 辣鸡！差评！差评差评 发货速度差辣鸡差评
# -----------------------------------------------------------
# origin: 感觉差，边上好多<UNK>，稍微有点刮手，而且表面漆也不好 | reconstruct: 色泽不是很好，一开始就褪色，还送了两个挂绳，不值这个价钱
# transfer_g: 这个真的很好啊，我戴在手上很好看，不过还可以免费刻字，就是有点单调 | transfer_b: 差差差，做工粗糙，差差差差差差差，还一股地方有划痕，无语
# -----------------------------------------------------------
# origin: 质量不好，根本夹不住头发， | reconstruct: 质量不好，扣不住头发，松
# transfer_g: 看着很好用，但是我带不大了 | transfer_b: 差，差差结实粗糙
# -----------------------------------------------------------
# origin: 垃圾东西，没想到在京东上也有垃圾货骗人 | reconstruct: 垃圾东西，在京东上也要***
# transfer_g: 是我在京东买东西 没有色差 以后还在来买&hellip; | transfer_b: 垃圾，物流速度差****，******
# -----------------------------------------------------------
# origin: 一点都不满意！特别是绳子！没用几天就断了！貔貅也成玻璃渣了！碎的！ | reconstruct: 一点都不满意！一点都不耐磨！拿回来都断了！一点都不耐磨！上面的花也不亮！
# transfer_g: 我觉得太不太喜欢了！一点都不像<UNK>上都是很好看，不知道会不会生锈！ | transfer_b: 差严重不符！严重不符！做工不精细！差差差！差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评
# -----------------------------------------------------------
# origin: 女款和网上图片不一样，字也刻歪了，有点长 | reconstruct: 照片和实物不一样，字也刻歪了，戒指有点大
# transfer_g: 这我戴着感觉很好看 我和照片上一样 媳妇很满意！！ | transfer_b: 与描述不符，链子太细严重不符，做工也不咋地！
# -----------------------------------------------------------
# origin: 质量不怎么样 总体感觉还行吧 毕竟价格在那里 | reconstruct: 还行 就是感觉质量不咋地 有待加强
# transfer_g: 感觉还不错 不过我觉得质量真的是太多了 | transfer_b: 一般般吧 做工差 价格与地摊货不符凑合
# -----------------------------------------------------------
# origin: 不实用，用不到。 | reconstruct: 不实用，不能用。
# transfer_g: 女儿说很好看，就是有点用？ | transfer_b: 结实，一分钱一分货。差评
# -----------------------------------------------------------
# origin: 实物与网上照片有差异，不太理想，真实点应该可以持久 | reconstruct: 实物与图片有差距，仅仅还可以，就是不知道是不是真的，好评
# transfer_g: 东西跟图片上看起来很好看，个人觉得还可以，戴着玩玩很好看。 | transfer_b: 包装与描述不符，有些粗糙，与实物有差距，一分钱一分货吧
# -----------------------------------------------------------
# origin: 买回来第二天就断了。换了送的皮筋。第3天又断了。。看来不适合我 | reconstruct: 刚开始就断了。。。妈的时候只发了一个？？？？？？质量还行？
# transfer_g: 这个我戴了几天才来评价了。很喜欢。还送了我的蝴蝶结？？？？？？？？？？？？ | transfer_b: 太差了。其中一个坏的。包装差渣渣。最多了，最多再差评！
# -----------------------------------------------------------
# origin: 有点重，物流有点慢，快递大哥辛苦了 | reconstruct: 有点失望，物流有点慢，其馀可以啦
# transfer_g: 我还很喜欢，但感觉有点贵，我老婆很高兴 | transfer_b: 差评，包装一般般，送货速度有些慢！
# -----------------------------------------------------------
# origin: 怎么<UNK>不了，怎么扣的 | reconstruct: 怎么<UNK><UNK>吗，怎么扣的
# transfer_g: 我只能<UNK><UNK><UNK><UNK>用有点小，不是很好看的 | transfer_b: 容易坏，里面还不是<UNK>的。
# -----------------------------------------------------------
# origin: 好小好小呀，和想象的出入太大了 | reconstruct: 就是比想象中的小， <UNK>死了
# transfer_g: 我觉得小了点，朋友都挺好看的<UNK> | transfer_b: 差的要死，色泽不行，发货太慢了
# -----------------------------------------------------------
# origin: 不好看不好看 | reconstruct: 不好看不好看
# transfer_g: 我好看好看不好看很喜欢 | transfer_b: 不结实，不
# -----------------------------------------------------------
# origin: 还行挺好看的 | reconstruct: 还行挺好看的
# transfer_g: 感觉好看很喜欢的 | transfer_b: 比较满意吧，结实
# ===========================================================
# epoch:8==================================================
# INFO:tensorflow:Restoring parameters from /root/VAE/char_vae_model/runs/1513220661/model-8
# restore /root/VAE/char_vae_model/runs/1513220661/model-8 success
# -----------------------------------------------------------
# 不实用，用不上
# 不知道，干什么用
# 好长，不实用。
# 唔，不好看哦。
# 恩，挺好看。
# 恩，挺好看。很喜欢
# 价格便宜，很好看，值得购买！
# 价格便宜，很不错，建议购买！
# 很不错，价格合理，做工精细！
# 很不错，价格合理，做工精细，值得购买！
# 很不错，价格便宜，做工精细，值得购买，
# 很不错，做工精细，物有所值，值得购买，
# -----------------------------------------------------------
# 垃圾，发货慢的要死
# 垃圾，发货慢的要死
# 垃圾，商品一样的！
# 好，发货太慢了，比较满意
# 好，发货速度，棒棒哒！
# 货真价实，质量好，女朋友很满意。
# 货真价实，质量好，女朋友很满意。
# 很漂亮，质量好，价格公道！很满意
# 很漂亮，质量好，价格很合适，满意！
# 很不错，价格便宜，做工精细，值得购买
# 很不错，价格便宜，做工精细，值得购买，
# 很不错，做工精细，物有所值，值得购买，
# good:我很喜欢 | bad:差评
# -----------------------------------------------------------
# origin: 不错很合适 | reconstruct: 不错很合适
# transfer_g: 款式很不错带很很好看 | transfer_b: 可以 比较满意吧
# -----------------------------------------------------------
# origin: 质量，不错，很美美哒拉风。 第二次购买了，发货很快，质量有保障 | reconstruct: 质量不错，价格便宜，很喜欢这款，做工精细，性价比高，给5分。
# transfer_g: 项链不错，质量很好，款式我很喜欢，带着很漂亮，卖家发货很快了，祝生意兴隆 | transfer_b: good，good！！！！！！！！！！！性价比高，还算划算！
# -----------------------------------------------------------
# origin: 商品本身还行，就是有点卡头发 | reconstruct: 商品还算行，就是卡口有点松
# transfer_g: 项链色泽真的很好 带着有点小很霸气。 | transfer_b: 还凑合，性价比差差过得去吧！
# -----------------------------------------------------------
# origin: 感觉还可以，不错，真心不错。 | reconstruct: 感觉还不错，嗯，很喜欢。
# transfer_g: 东西感觉很不错，带着很漂亮，很好看。 | transfer_b: 一般般吧，一分钱一分货，，。。
# -----------------------------------------------------------
# origin: 送给情人的 非常满意 谢谢热情的卖家 | reconstruct: 送给朋友的 非常满意 谢谢卖家的礼物
# transfer_g: 项链是我喜欢的款式 很好卖家包装也很好 | transfer_b: 愉快的，愉快的一次购物 五星好评
# -----------------------------------------------------------
# origin: 老婆很喜欢，很满意。 | reconstruct: 老婆很喜欢，很好看。
# transfer_g: 手链我很喜欢，我很好看。 | transfer_b: 大赞，！！！！
# -----------------------------------------------------------
# origin: 太好了，不错很喜欢 | reconstruct: 不错，特别快！
# transfer_g: 款式很好 很漂亮 我喜欢 | transfer_b: ，！！
# -----------------------------------------------------------
# origin: 东西非常好，快递很快，昨天下的单今天就到了，谢谢了 | reconstruct: 东西非常好，物流很快，昨天定的今天就到了，辛苦了
# transfer_g: 东西东西我好喜欢，和图片一样漂亮 我和男朋友都很喜欢，下次还来这家店买了 | transfer_b: 辣鸡，快递慢的，服务差！下次不要再来！
# -----------------------------------------------------------
# origin: 下次还来，老板记得给打个折哦 | reconstruct: 下次还会来光顾，下次还要来你家买
# transfer_g: 东西很漂亮同事都问我在哪里买，女朋友很喜欢 | transfer_b: 1，下次再追加追加评论！追加
# -----------------------------------------------------------
# origin: 卡子挺漂亮的，就是太沉了 | reconstruct: 夹子挺漂亮的，就是选小了
# transfer_g: 项链好喜欢颜色搭配的颜色很好看 | transfer_b: 结实的，一分钱一分货吧！
# -----------------------------------------------------------
# origin: 失望透了 | reconstruct: 货到了<UNK>
# transfer_g: 我和宝贝都很喜欢了 | transfer_b: 差评吧！
# -----------------------------------------------------------
# origin: 大家不要买，质量又不好，感觉像**的地摊货 | reconstruct: 大家不要买，一点都不好，感觉不值这么多钱的！
# transfer_g: 戒指比我想像中好一点都好看，带了好几天了，也不会变色。 | transfer_b: **，***，***的，一分钱一分货！
# -----------------------------------------------------------
# origin: 速速慢啊 还没有送到 | reconstruct: 什么东西啊 还未使用
# transfer_g: 我觉得质量很好啊 颜色跟真的 | transfer_b: 哎差差，差差差差差差
# -----------------------------------------------------------
# origin: 没得说！ | reconstruct: 没得说！
# transfer_g: 链子很好喜欢 | transfer_b: ！！
# -----------------------------------------------------------
# origin: 快递太慢，女朋友不满意，<UNK>早日关门。 | reconstruct: 快递太慢，戒指很不给力，我不想知道她喜不喜欢。
# transfer_g: 项链我很喜欢，我和我女朋友都不一样，就是快递有点慢 | transfer_b: 太慢，差评！@@@@@。@@
# -----------------------------------------------------------
# origin: 快递好慢！ 必须差评差评差评 差评差评差评 | reconstruct: 快递太慢！差评！一星也不想给 差评
# transfer_g: 东西我很喜欢 就是物流太慢了 5天才到 差评 | transfer_b: 辣鸡！差评！差评！辣鸡快递的速度好慢
# -----------------------------------------------------------
# origin: 感觉差，边上好多<UNK>，稍微有点刮手，而且表面漆也不好 | reconstruct: 貔貅有点大，一点都不好，而且还没有用过呢，希望大家谨慎改进，
# transfer_g: 东西都很好带在手上很好看，就是有点小一点都没有掉，链子也很好，两天就到了。 | transfer_b: 很差，差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差，差差差差，差差差差差差
# -----------------------------------------------------------
# origin: 质量不好，根本夹不住头发， | reconstruct: 质量不好，老是夹不住，不住
# transfer_g: 项链很好，带了一点都没有戴 | transfer_b: 差，差差差差，凑合般般的
# -----------------------------------------------------------
# origin: 垃圾东西，没想到在京东上也有垃圾货骗人 | reconstruct: 垃圾东西，在京东上快递也这么慢
# transfer_g: 跟真的都是真的一样 在在这家买东西都没真的好 | transfer_b: 垃圾，下次有机会服务差，快递也慢
# -----------------------------------------------------------
# origin: 一点都不满意！特别是绳子！没用几天就断了！貔貅也成玻璃渣了！碎的！ | reconstruct: 一点都不满意！戴了不到一个月都不受理，不咋地不咋地！骗人的一次购物！
# transfer_g: 戒指特别是太喜欢了我颜色都没有图片上颜色太深了，不知道是不是真的太<UNK>了一点都不好看！我很喜欢 | transfer_b: 差评差差差差差差！！差差差差差差！严重不咋的！差差差差差差差差差差差评！差差差差差差差评
# -----------------------------------------------------------
# origin: 女款和网上图片不一样，字也刻歪了，有点长 | reconstruct: 照片和实物不一样，其馀来说也太短了，不是很理想
# transfer_g: 这颜色我和颜色都一样颜色也很喜欢，颜色我戴着也很好看。 | transfer_b: 差评差差差差差差，凑合吧，物流速度不咋地
# -----------------------------------------------------------
# origin: 质量不怎么样 总体感觉还行吧 毕竟价格在那里 | reconstruct: 还行 就是感觉质量不咋地 一分价钱一分货
# transfer_g: 东西不错就是颜色太深了也不是很好带着也有份量 | transfer_b: 一般吧，送货速度也过得去凑合凑合吧
# -----------------------------------------------------------
# origin: 不实用，用不到。 | reconstruct: 不实用，不会用。
# transfer_g: 我带着很好看，不会过敏。 | transfer_b: 哎，一分钱一分货。没用。
# -----------------------------------------------------------
# origin: 实物与网上照片有差异，不太理想，真实点应该可以持久 | reconstruct: 实物与照片有差异，但还算满意，毕竟是赠送品！
# transfer_g: 项链和图片上一样没有色差，带在手上感觉很不错，款式也很好看。 | transfer_b: 与实物不符，一分钱一分货，还有一分钱一分货吧。过得去
# -----------------------------------------------------------
# origin: 买回来第二天就断了。换了送的皮筋。第3天又断了。。看来不适合我 | reconstruct: 买来断了。本来想退货的时候换了一下。现在才收到。现在也很喜欢。
# transfer_g: 项链我已经戴了几天了都很喜欢。颜色比我想象中的要好。这个价位买了两款。 | transfer_b: 特么的！还不到一个星期就断了！！！再一个！骗子！！！！！！！！！！！！！！！
# -----------------------------------------------------------
# origin: 有点重，物流有点慢，快递大哥辛苦了 | reconstruct: 有点慢，物流很慢，一分价钱一分货吧
# transfer_g: 货真的很不错，就是链子有点<UNK>，带着特别特别 | transfer_b: 一般般，一分钱一分货。快递一般般，服务一般般
# -----------------------------------------------------------
# origin: 怎么<UNK>不了，怎么扣的 | reconstruct: 怎么<UNK><UNK><UNK><UNK>，怎么不是银的
# transfer_g: 我我我我我<UNK>我<UNK><UNK>有点大我带有点大，很好看 | transfer_b: 凑合十个字，怎么<UNK>的<UNK>。
# -----------------------------------------------------------
# origin: 好小好小呀，和想象的出入太大了 | reconstruct: 就是比想象中的小，<UNK>……&hellip;
# transfer_g: 戒指小了和图片一样好看啊，带上很好 | transfer_b: 假的，还凑合吧！！
# -----------------------------------------------------------
# origin: 不好看不好看 | reconstruct: 不好看不好看
# transfer_g: 我带好看颜色很好看 | transfer_b: 不实用的
# -----------------------------------------------------------
# origin: 还行挺好看的 | reconstruct: 还行挺好看的
# transfer_g: 项链好看我挺好看好看好看 | transfer_b: 实用的吧
# ===========================================================
# epoch:9==================================================
# INFO:tensorflow:Restoring parameters from /root/VAE/char_vae_model/runs/1513220661/model-9
# restore /root/VAE/char_vae_model/runs/1513220661/model-9 success
# -----------------------------------------------------------
# 不实用，用不上
# 不知道，干什么用
# 满好看，挺好玩？
# 不赖，小朋友很喜欢。
# 不赖，小朋友挺喜欢。
# 挺美的，好看，女朋友很喜欢。
# 价格便宜，很好看，值得购买！
# 很好看，价格便宜，值得购买，好评
# 很好看，价格便宜，做工不错，值得购买
# 很不错，正品，质量可靠，好评！
# 很不错，正品，质量过关，值得购买
# 很不错，做工精细，物有所值，值得购买，
# -----------------------------------------------------------
# 垃圾，发货慢的要死
# 垃圾，发货慢的要死
# 垃圾，发货慢的要死
# 好评，质量和描述的一样
# 好评，质量好，绝对满意
# 货真价实，质量好，给个好评
# 很漂亮，质量没话说，非常满意！
# 价格便宜，质量不错，很满意这次网购
# 很好，速度很快，做工精致，喜欢！
# 很不错，价格便宜，做工精细，值得购买！
# 质量不错，很满意，价格优惠，很漂亮！
# 很不错，做工精细，物有所值，值得购买，
# good:我很喜欢 | bad:差评
# -----------------------------------------------------------
# origin: 不错很合适 | reconstruct: 不错很合适
# transfer_g: 很不错朋友很好 | transfer_b: 结实！一般般
# -----------------------------------------------------------
# origin: 质量，不错，很美美哒拉风。 第二次购买了，发货很快，质量有保障 | reconstruct: 质量不错，做工精细，很喜欢，店主还送了小礼物，赞一个，好评。
# transfer_g: 项链不错哦，很喜欢，质量很好，下次还会在来买哦很满意 | transfer_b: 差，做工差，！！！！！！！！！！！！！！！！！！！！！！！！！！
# -----------------------------------------------------------
# origin: 商品本身还行，就是有点卡头发 | reconstruct: 看着还行，就是那个有点缺陷
# transfer_g: 东西确实很不错带在身上也很好 | transfer_b: 做工粗糙，一般般有些粗糙，不值这价
# -----------------------------------------------------------
# origin: 感觉还可以，不错，真心不错。 | reconstruct: 感觉还不错，嗯，挺好。
# transfer_g: 东西感觉不错哦，很不错很好看 | transfer_b: 一般般吧，价格一般，，。。。。
# -----------------------------------------------------------
# origin: 送给情人的 非常满意 谢谢热情的卖家 | reconstruct: 非常满意的一次网购，送的礼物也很漂亮
# transfer_g: 给朋友买的非常不错 我非常给力很满意 | transfer_b: 差评！差评的，做工杠杠的，骗子
# -----------------------------------------------------------
# origin: 老婆很喜欢，很满意。 | reconstruct: 很喜欢呢，很满意。
# transfer_g: 东西很好看我很喜欢哦 | transfer_b: 差评！！！！！！
# -----------------------------------------------------------
# origin: 太好了，不错很喜欢 | reconstruct: 很漂亮，质量很好！
# transfer_g: 真的很不错哦 我很喜欢 | transfer_b: ，！！！！！
# -----------------------------------------------------------
# origin: 东西非常好，快递很快，昨天下的单今天就到了，谢谢了 | reconstruct: 东西非常好，物流很快，昨天定的今天就到了，感谢卖家了
# transfer_g: 东西东西很好哦，我朋友非常喜欢 下次还会在来买的物流很快 | transfer_b: 差差差，差评，物流太慢了，慢的要死。发货速度太慢了
# -----------------------------------------------------------
# origin: 下次还来，老板记得给打个折哦 | reconstruct: 老板人好，下次需要还来你家买东西
# transfer_g: 给朋友买东西朋友很喜欢下次有需要还会在来 | transfer_b: 差评，渣渣渣，五天才到货！差评！
# -----------------------------------------------------------
# origin: 卡子挺漂亮的，就是太沉了 | reconstruct: 质量杠杠的，带起来很漂亮！
# transfer_g: 项链很好看哦好喜欢的说 | transfer_b: 一般般，做工粗糙！难看！！！
# -----------------------------------------------------------
# origin: 失望透了 | reconstruct: 和想象哒？
# transfer_g: 我朋友很喜欢好 | transfer_b: 差评！！！
# -----------------------------------------------------------
# origin: 大家不要买，质量又不好，感觉像**的地摊货 | reconstruct: 大家不要买，质量真心不好，便宜没好货就是假的
# transfer_g: 这真的好好哦好说好是好用 下次还会在来 | transfer_b: 差，一拉就断了，差差差，差差差！差！差
# -----------------------------------------------------------
# origin: 速速慢啊 还没有送到 | reconstruct: 没有什么问题 快递还可以哦
# transfer_g: 赠品我很好东西也很漂亮 | transfer_b: 差评，差差差差差差一般般一般般
# -----------------------------------------------------------
# origin: 没得说！ | reconstruct: 没得说！
# transfer_g: 礼物很好喜欢 | transfer_b: 差评！！！
# -----------------------------------------------------------
# origin: 快递太慢，女朋友不满意，<UNK>早日关门。 | reconstruct: 快递太慢，很不满意，给我一个星期才到。
# transfer_g: 东西我很喜欢，下次我也很给力，下次有需要还来 | transfer_b: 不行，差评。差评！差评！差评！差评，根本不行
# -----------------------------------------------------------
# origin: 快递好慢！ 必须差评差评差评 差评差评差评 | reconstruct: 快递太慢！差评！ 一星都不想给！
# transfer_g: 东西给力 我非常喜欢下次还会再来的 | transfer_b: 差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评！差评！差评！差评！差差差差差差差评！差评差评差评
# -----------------------------------------------------------
# origin: 感觉差，边上好多<UNK>，稍微有点刮手，而且表面漆也不好 | reconstruct: 绳子一点都不好，还没扎，<UNK>也不值这个价，还不如图片上<UNK>。
# transfer_g: 东西真的很有质感 带在身上很有感觉啊 东西很好很有质感 下次还在买 | transfer_b: 不行，差差差差差差差差差，根本不行，根本不行，根本不值绳子不行，根本不值。差差差差差差差差差差差差
# -----------------------------------------------------------
# origin: 质量不好，根本夹不住头发， | reconstruct: 质量不好，扣子扣不住头发，不好
# transfer_g: 东西很好用 同事都说好看 | transfer_b: 差，差差差，掉漆断了！
# -----------------------------------------------------------
# origin: 垃圾东西，没想到在京东上也有垃圾货骗人 | reconstruct: 垃圾东西，在京东上看到东西也要卖
# transfer_g: 是我朋友说东西好卖家服务态度好下次还在这家店买东西 | transfer_b: 垃圾，根本就垃圾垃圾，差差差差差差差差差
# -----------------------------------------------------------
# origin: 一点都不满意！特别是绳子！没用几天就断了！貔貅也成玻璃渣了！碎的！ | reconstruct: 一点都不满意！根本都掉漆了！而且一点都不真实！渣渣渣的厉害！
# transfer_g: 这对手真的非常好看我很喜欢这款项链都是我喜欢的那种太俗气了(￣;￣) | transfer_b: 差评严重严重不符！太差劲！严重不符！严重不符！掉漆严重！差评！太难看了！根本不结实严重不符！差评
# -----------------------------------------------------------
# origin: 女款和网上图片不一样，字也刻歪了，有点长 | reconstruct: 照片和实物不一样，铃铛也懒得换了，不是很好闻
# transfer_g: 这款手链真的是很好看 我朋友也觉得很不错我很喜欢 | transfer_b: 差评差评，根本掉颜色不符，做工不行！根本不结实！差差差差
# -----------------------------------------------------------
# origin: 质量不怎么样 总体感觉还行吧 毕竟价格在那里 | reconstruct: 还行 就是感觉质量不咋地 一分钱一分货
# transfer_g: 东西不错也不错带起来也很好下次还会再来 | transfer_b: 一般般，做工有些粗糙吧！价格也不值质量差
# -----------------------------------------------------------
# origin: 不实用，用不到。 | reconstruct: 不实用，还要用。
# transfer_g: 女儿说很好看下次还会买 | transfer_b: 哎，容易坏！！！！
# -----------------------------------------------------------
# origin: 实物与网上照片有差异，不太理想，真实点应该可以持久 | reconstruct: 实物与图片有差异，不过整体还算满意，一分钱一分货吧
# transfer_g: 项链戴起来真的很好看东西也不错还有小礼品，下次还会光顾 | transfer_b: 与实物不符，一般般严重不符，有些不符，一分钱一分货吧。
# -----------------------------------------------------------
# origin: 买回来第二天就断了。换了送的皮筋。第3天又断了。。看来不适合我 | reconstruct: 买回来已经断了。本来想退货了。本来想退货了。说好的事情说三遍。还送了个耳钉。
# transfer_g: 这项链我朋友很喜欢哦！买了好几个人的朋友都要买呢！还送了小礼品。 | transfer_b: 太烂了。差差差差差差差差差差差评。差差差差差差差评。差差差差坏了。差差差差差差差评差评差评差评差评差评差评差评
# -----------------------------------------------------------
# origin: 有点重，物流有点慢，快递大哥辛苦了 | reconstruct: 一般般啦，商品不是很好，毕竟物流太慢。
# transfer_g: 东西不错我很喜欢还有赠品，物流也很给力 | transfer_b: 差评！一般般，一般般，根本不行！不行！
# -----------------------------------------------------------
# origin: 怎么<UNK>不了，怎么扣的 | reconstruct: 怎么<UNK>有点<UNK>嘞，小孩玩的
# transfer_g: 我觉得<UNK><UNK><UNK>用还很好看 | transfer_b: 差评有点松，根本太短了，差评。
# -----------------------------------------------------------
# origin: 好小好小呀，和想象的出入太大了 | reconstruct: 就是比想象中的大，<UNK>啦
# transfer_g: 东西是我买的小礼物很好用不错 | transfer_b: 差评，一拉断的不行！断了！
# -----------------------------------------------------------
# origin: 不好看不好看 | reconstruct: 不好看不好看
# transfer_g: 老婆好看我非常好看 | transfer_b: 不结实，不结实
# -----------------------------------------------------------
# origin: 还行挺好看的 | reconstruct: 戴起来挺实用的
# transfer_g: 感觉朋友很好看不错 | transfer_b: 结实，一般般！
# ===========================================================
# epoch:10==================================================
# INFO:tensorflow:Restoring parameters from /root/VAE/char_vae_model/runs/1513220661/model-10
# restore /root/VAE/char_vae_model/runs/1513220661/model-10 success
# -----------------------------------------------------------
# 不实用，用不上
# 不满意，不能用
# 不好看，差差差评
# 不满意，还行？
# 挺好看，媳妇儿很喜欢。
# 挺好，妞妞很喜欢！
# 很好看，质量也好，值得购买
# 很好，美观大方，不错！
# 很好，很漂亮，价格实惠！
# 很不错，价格合理，质量好，值得购买
# 质量不错，价格合理，很不错，值得购买。
# 很不错，做工精细，物有所值，值得购买，
# -----------------------------------------------------------
# 垃圾，发货慢的要死
# 垃圾，发货慢的要死了
# 垃圾，发货慢的要死了
# 差评，质量差，和卖家描述的一样
# 差评，质量好，发货速度挺快的
# 挺不错，质量好，发货迅速，满意
# 很棒，质量好，发货很快，满意
# 很漂亮，质量好，做工细致，很满意
# 很好，很漂亮，发货速度快，好评！
# 很好，很漂亮，做工精致，物流快！
# 质量不错，做工精致，很满意，下次还来，
# 很不错，做工精细，物有所值，值得购买，
# good:妈妈很喜欢啊 | bad:差评
# -----------------------------------------------------------
# origin: 不错很合适 | reconstruct: 不错很适合
# transfer_g: 我很喜欢带着很不错很好看 | transfer_b: 精致，0
# -----------------------------------------------------------
# origin: 质量，不错，很美美哒拉风。 第二次购买了，发货很快，质量有保障 | reconstruct: 质量不错，做工精细，很漂亮，同事见了都说很好看，赞一个！
# transfer_g: 东西收到了，真的很不错哦，很喜欢哦，戴着很舒服很漂亮，很喜欢这款手链。 | transfer_b: ，，，做工精细，质量好，发货速度快，5分。
# -----------------------------------------------------------
# origin: 商品本身还行，就是有点卡头发 | reconstruct: 戒指看着很好，只是没戴多久就会断
# transfer_g: 这个手链我很喜欢戴在手上感觉很舒服，很不错 | transfer_b: 做工粗糙，性价比粗糙
# -----------------------------------------------------------
# origin: 感觉还可以，不错，真心不错。 | reconstruct: 感觉还不错，价格便宜，值得拥有，
# transfer_g: 东西真的很不错哦，戴着也很好看，老婆很喜欢。 | transfer_b: 还好，，，价格不高，
# -----------------------------------------------------------
# origin: 送给情人的 非常满意 谢谢热情的卖家 | reconstruct: 送给朋友的 非常满意的一次购物 赞一个
# transfer_g: 老婆很喜欢送给朋友的她很喜欢 卖家服务态度也很好的 | transfer_b: 满意的，服务杠杠的
# -----------------------------------------------------------
# origin: 老婆很喜欢，很满意。 | reconstruct: 老婆很喜欢，很满意
# transfer_g: 老婆很喜欢很好看很喜欢很不错 | transfer_b: 满意，赞！
# -----------------------------------------------------------
# origin: 太好了，不错很喜欢 | reconstruct: 不错，非常好
# transfer_g: 真的很不错，朋友很喜欢 | transfer_b: ，，，
# -----------------------------------------------------------
# origin: 东西非常好，快递很快，昨天下的单今天就到了，谢谢了 | reconstruct: 东西收到了，和卖家描述的一样，客服态度也很好，下次还会光顾
# transfer_g: 东西已经收到了我很喜欢啊，款式也很好，以后还会再来你家买的 | transfer_b: 辣鸡，垃圾，发货慢的要死，服务差垃圾垃圾
# -----------------------------------------------------------
# origin: 下次还来，老板记得给打个折哦 | reconstruct: 下次还来你家，下次还来你家买？
# transfer_g: 给朋友买了朋友说很好看她也很喜欢下次还在这里买。 | transfer_b: 差评，5分5星
# -----------------------------------------------------------
# origin: 卡子挺漂亮的，就是太沉了 | reconstruct: 质量蛮好的，女友很喜欢
# transfer_g: 东西戴着很好看我很喜欢哦！挺喜欢的 | transfer_b: 做工，差，好评
# -----------------------------------------------------------
# origin: 失望透了 | reconstruct: 货到了很多
# transfer_g: 我朋友看了很喜欢 | transfer_b: 垃圾，辣鸡
# -----------------------------------------------------------
# origin: 大家不要买，质量又不好，感觉像**的地摊货 | reconstruct: 一点都不好，不过便宜没好货，大家不要买吧！
# transfer_g: 感觉我女儿用了个个都说很好看，质量也很好。下次还会再来买 | transfer_b: 差，差差差，送货差，建议别买
# -----------------------------------------------------------
# origin: 速速慢啊 还没有送到 | reconstruct: 没有想象中那么好 快递小哥
# transfer_g: 我朋友看了很好很好好也很好 | transfer_b: 差，服务差
# -----------------------------------------------------------
# origin: 没得说！ | reconstruct: good，马马虎虎
# transfer_g: 老婆很喜欢，嘿嘿 | transfer_b: 差评，辣鸡
# -----------------------------------------------------------
# origin: 快递太慢，女朋友不满意，<UNK>早日关门。 | reconstruct: 快递太慢，女朋友很生气，我都不知道什么时候。
# transfer_g: 这个我老婆很喜欢，我老婆带上很高兴，我也很高兴。我很高兴啊 | transfer_b: 辣鸡，差评，差评差评差评差评差评
# -----------------------------------------------------------
# origin: 快递好慢！ 必须差评差评差评 差评差评差评 | reconstruct: 快递太慢了，差评差评差评差评差评差评
# transfer_g: 东西已经收到了很喜欢521快递小哥也不给我了，五星好评 | transfer_b: 辣鸡，辣鸡差评差评差评差评辣鸡辣鸡辣鸡
# -----------------------------------------------------------
# origin: 感觉差，边上好多<UNK>，稍微有点刮手，而且表面漆也不好 | reconstruct: 一点都不好，而且还没有<UNK>，而且也很结实，希望以后不会再买
# transfer_g: 这款很好看啊很好看啊，戴在脖子上感觉很舒服，颜色也很好，我很喜欢这款<UNK> | transfer_b: 差，抛光差，抛光差，个别个别有瑕疵
# -----------------------------------------------------------
# origin: 质量不好，根本夹不住头发， | reconstruct: 质量太差，<UNK>有残缺就坏了
# transfer_g: 东西真的很好看戴着很舒服，戴在脖子上很好 | transfer_b: 差，差，好容易上锈
# -----------------------------------------------------------
# origin: 垃圾东西，没想到在京东上也有垃圾货骗人 | reconstruct: 垃圾东西，有一颗星也就和快递小哥服务态度差
# transfer_g: 是我在网上看了看东西也很好 下次在这里买东西也没让我失望 | transfer_b: 垃圾，垃圾，发货速度有垃圾
# -----------------------------------------------------------
# origin: 一点都不满意！特别是绳子！没用几天就断了！貔貅也成玻璃渣了！碎的！ | reconstruct: 一点都不满意！一点都不一样！戴了一天就掉了！一点也不真实！
# transfer_g: 戒指特别好看我戴了很久脖子上不太好看了&hellip;真的很好看&hellip;不知道褪了会不会褪色& | transfer_b: 差评！严重不符！一点不符！一点不不符！渣渣渣渣渣渣渣渣渣渣
# -----------------------------------------------------------
# origin: 女款和网上图片不一样，字也刻歪了，有点长 | reconstruct: 实物与图片完全不一样，戒指太小了，毕竟一分价钱一分货
# transfer_g: 这款手链我很喜欢颜色也没有色差，戴在手上感觉很好看！总之很满意！ | transfer_b: 差评，与描述不符，做工粗糙严重不符
# -----------------------------------------------------------
# origin: 质量不怎么样 总体感觉还行吧 毕竟价格在那里 | reconstruct: 还行吧 一分钱一分货 感觉不值这个价
# transfer_g: 感觉还不错&hellip;很好看 &hellip;就是稍微小了一点 不知道会不会褪色 | transfer_b: 一般，一分钱一分货，送货速度太慢
# -----------------------------------------------------------
# origin: 不实用，用不到。 | reconstruct: 不好用，不知道好不好。
# transfer_g: 用起来很好看，我女儿很喜欢呢！ | transfer_b: 垃圾，假货，一分货
# -----------------------------------------------------------
# origin: 实物与网上照片有差异，不太理想，真实点应该可以持久 | reconstruct: 实物与图片有差距，不过物流太慢了，毕竟一分价钱一分货，
# transfer_g: 今天刚拿到手感觉很好看跟图片上一样，戴在脖子上也很舒服，老婆很喜欢。 | transfer_b: 与描述不符，一分钱一分货，凑合发货，速度太慢
# -----------------------------------------------------------
# origin: 买回来第二天就断了。换了送的皮筋。第3天又断了。。看来不适合我 | reconstruct: 链子太不靠谱了。买了20天才到。还送了个棒棒糖。我也懒得退货了。。。。。。。。
# transfer_g: 这手链我戴了段时间了才来评价了很喜欢。戴在脖子上也很舒服。我很喜欢这款了。很喜欢 | transfer_b: 差差差，差评差评差评差评差评差评差评差评。差评差评差评差评差评差评！差评差评差评差评差评差评差评差评差评差评差评差评
# -----------------------------------------------------------
# origin: 有点重，物流有点慢，快递大哥辛苦了 | reconstruct: 一般般，快递员态度很好，就是物流有点慢
# transfer_g: 老婆很喜欢虽然有点小失望，但我觉得质量很好，下次还来买 | transfer_b: 差评，，送货慢服务不行
# -----------------------------------------------------------
# origin: 怎么<UNK>不了，怎么扣的 | reconstruct: 怎么<UNK><UNK><UNK><UNK>，不是云的
# transfer_g: 我我只能说<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>有点大不过很好看 | transfer_b: 差评，差差差差差差
# -----------------------------------------------------------
# origin: 好小好小呀，和想象的出入太大了 | reconstruct: 就是比想象中小，<UNK>的感觉
# transfer_g: 我觉得戴了几天感觉很好很漂亮，朋友都说好看。 | transfer_b: 差，其他的，地摊货
# -----------------------------------------------------------
# origin: 不好看不好看 | reconstruct: 非常好看不好看
# transfer_g: 我感觉非常好看她很喜欢 | transfer_b: 不满意
# -----------------------------------------------------------
# origin: 还行挺好看的 | reconstruct: 感觉挺漂亮的
# transfer_g: 感觉我戴着挺好看的 | transfer_b: 一般吧
# ===========================================================
# epoch:11==================================================
# INFO:tensorflow:Restoring parameters from /root/VAE/char_vae_model/runs/1513220661/model-11
# restore /root/VAE/char_vae_model/runs/1513220661/model-11 success
# -----------------------------------------------------------
# 不实用，用不上
# 不好看，卡哇伊
# 不孬，可以用
# 挺好看，小孩子很喜欢
# 挺好看，孩子很喜欢
# 挺好看，孩子很喜欢！
# 很好看，值得购买，好评！
# 很好看，质量也好，值得购买
# 很好，价格实惠，很喜欢！
# 很好，质量不错，值得购买。
# 很好，质量不错，值得购买，好评。
# 很不错，做工精细，物有所值，值得购买，
# -----------------------------------------------------------
# 垃圾，发货慢的要死
# 好评，和描述的一样
# 好评，和描述的一样
# 好评，东西挺好的
# 好评，东西挺好的。
# 好评，东西挺好的。
# 不错，发货速度快，很满意的一次购物
# 很漂亮，质量也很好，值得购买。
# 很漂亮，质量也不错，值得购买。
# 很漂亮，质量很好，价格实惠，值得购买
# 质量不错，很漂亮，性比价高，非常满意。
# 很不错，做工精细，物有所值，值得购买，
# good:<UNK>喜欢 | bad:不太理想
# -----------------------------------------------------------
# origin: 不错很合适 | reconstruct: 不错 我很喜欢
# transfer_g: 好不错我很喜欢 | transfer_b: 一般般 ok
# -----------------------------------------------------------
# origin: 质量，不错，很美美哒拉风。 第二次购买了，发货很快，质量有保障 | reconstruct: 做工精致，质量很好，还送了小礼物，非常喜欢，下次还会再来。
# transfer_g: 很好哦，好喜欢哦。质量不错。值得购买。下次还会再来这家店买的。 | transfer_b: 发货很快，包装完好，做工也可以，还送了一个棒棒糖。
# -----------------------------------------------------------
# origin: 商品本身还行，就是有点卡头发 | reconstruct: 戒指看上去还行，<UNK>很大气
# transfer_g: 戒指很好用。好搭配衣服不错。 | transfer_b: 项链有点瑕疵，总体还可以
# -----------------------------------------------------------
# origin: 感觉还可以，不错，真心不错。 | reconstruct: 东西不错，感觉还可以，挺好的。
# transfer_g: 东西不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错啊。。。。。。。 | transfer_b: 东西还可以吧，，，，，，，，
# -----------------------------------------------------------
# origin: 送给情人的 非常满意 谢谢热情的卖家 | reconstruct: 送给朋友的礼物，非常满意的一次购物
# transfer_g: 非常喜欢的好朋友很喜欢下次还会再来的哦 | transfer_b: 送给女朋友的礼物，物流也挺快的
# -----------------------------------------------------------
# origin: 老婆很喜欢，很满意。 | reconstruct: 老婆很喜欢，很满意。
# transfer_g: 不错很好很喜欢。值得购买。 | transfer_b: 发货速度很快，很满意
# -----------------------------------------------------------
# origin: 太好了，不错很喜欢 | reconstruct: 不错，很满意
# transfer_g: 好不错，很喜欢。 | transfer_b: 可以，，，
# -----------------------------------------------------------
# origin: 东西非常好，快递很快，昨天下的单今天就到了，谢谢了 | reconstruct: 东西收到了，和卖家描述的一样，快递小哥态度好，必须五星
# transfer_g: 东西好好好好好好好好好好好好好好好好好喜欢好喜欢好喜欢好东西好喜欢好喜欢好喜欢 | transfer_b: 东西没收到，发货速度超慢，物流超慢，差评差评差评差评
# -----------------------------------------------------------
# origin: 下次还来，老板记得给打个折哦 | reconstruct: 第一次在京东买东西，物流也很给力，赞一个
# transfer_g: 真的好喜欢哦下次还会在来哦，祝老板生意兴隆哦 | transfer_b: 收都没收到货，快递也够慢
# -----------------------------------------------------------
# origin: 卡子挺漂亮的，就是太沉了 | reconstruct: 还可以，就是稍微大了点
# transfer_g: 不错不错不错不错好喜欢好漂亮哦。 | transfer_b: 链子太短，做工还可以
# -----------------------------------------------------------
# origin: 失望透了 | reconstruct: 太小了
# transfer_g: 好喜欢好喜欢哦 | transfer_b: 链子太短
# -----------------------------------------------------------
# origin: 大家不要买，质量又不好，感觉像**的地摊货 | reconstruct: 真*****，*********，
# transfer_g: 好漂亮好喜欢好买买买买买买买买买买买买买买买买买。。。。。。 | transfer_b: 差差差，根本就打不开，差差差
# -----------------------------------------------------------
# origin: 速速慢啊 还没有送到 | reconstruct: 客服很好，货还可以
# transfer_g: 好东西很好值得购买哦 | transfer_b: 发货太慢，还没有刻字
# -----------------------------------------------------------
# origin: 没得说！ | reconstruct: 太差了，
# transfer_g: 好喜欢好！ | transfer_b: 辣鸡 差评
# -----------------------------------------------------------
# origin: 快递太慢，女朋友不满意，<UNK>早日关门。 | reconstruct: 物流太慢，东西很不满意，<UNK>才送到。
# transfer_g: 很好，我很喜欢。下次还来京东买东西。 | transfer_b: 根本没收到货，差评，物流还不对
# -----------------------------------------------------------
# origin: 快递好慢！ 必须差评差评差评 差评差评差评 | reconstruct: 快递太慢了，说好的刻字十五个字十五个没刻
# transfer_g: 好好好！我喜欢京东商城的快递小哥辛苦了！祝福你生意兴隆 | transfer_b: 根本没收到货 差评 差评 差评差评差评差评差评差评差评差评
# -----------------------------------------------------------
# origin: 感觉差，边上好多<UNK>，稍微有点刮手，而且表面漆也不好 | reconstruct: 一点也不好，<UNK><UNK>，还没戴一天就坏了，不值这个价
# transfer_g: 很好用，弹性很好，要是在大一点就好了一点就更好看了。 | transfer_b: 根本没有，彩虹眼，珠子也没有彩虹眼，根本没法用
# -----------------------------------------------------------
# origin: 质量不好，根本夹不住头发， | reconstruct: 太差，容易断，<UNK>就断了
# transfer_g: 很好用，建议大家不要买了一点。 | transfer_b: 差差差，绳子太短太短
# -----------------------------------------------------------
# origin: 垃圾东西，没想到在京东上也有垃圾货骗人 | reconstruct: 垃圾东西也没见到，请大家不要在京东购物。
# transfer_g: 好奇葩好奇葩好奇葩好奇葩是我在京东上买东西放心放心买！ | transfer_b: 差评差评差评，根本根本没发票，发票也没开
# -----------------------------------------------------------
# origin: 一点都不满意！特别是绳子！没用几天就断了！貔貅也成玻璃渣了！碎的！ | reconstruct: 一点都不咋地，买回来就坏了，从来不知道是不是真的银的吗？欺骗消费者
# transfer_g: 非常好我非常喜欢！要是在柜台就更好看了会不会掉漆！非常好的一次购物！ | transfer_b: 根本不咋地，根本根本不咋地，根本不咋地，差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评
# -----------------------------------------------------------
# origin: 女款和网上图片不一样，字也刻歪了，有点长 | reconstruct: 链子不咋地，其馀都不清楚，而且吊坠太大了
# transfer_g: 真的很好带起来很舒服，整个人都说很漂亮！建议大家购买！ | transfer_b: 根本与图不符 大小也不合适 差评 差评
# -----------------------------------------------------------
# origin: 质量不怎么样 总体感觉还行吧 毕竟价格在那里 | reconstruct: 还行吧，就是感觉质量太差
# transfer_g: 不错好不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错 | transfer_b: 速度太慢，也不咋地，凑合凑合
# -----------------------------------------------------------
# origin: 不实用，用不到。 | reconstruct: 不好用，不实用。
# transfer_g: 好用，好用。用起来方便。 | transfer_b: 不结实，差评，差评
# -----------------------------------------------------------
# origin: 实物与网上照片有差异，不太理想，真实点应该可以持久 | reconstruct: 实物与图片差距很大，略有色差，总体来说还可以吧
# transfer_g: 真的很好。比实体店便宜多了。色泽也不错。 | transfer_b: 链子与实物不符，包装也很大气，一般般
# -----------------------------------------------------------
# origin: 买回来第二天就断了。换了送的皮筋。第3天又断了。。看来不适合我 | reconstruct: 买来送人了。。。。。。。。拿回来的时候就断了。。。。。。。。。。。。。。
# transfer_g: 女儿很喜欢。用了一段时间才来评价了。好漂亮。买了两个。以后还会继续关注这家店的。。。。。 | transfer_b: 买来只有一个坏的，差评差评！差评！差评！差评差评！差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评
# -----------------------------------------------------------
# origin: 有点重，物流有点慢，快递大哥辛苦了 | reconstruct: 可以，就是物流有点慢，别的都不想说了
# transfer_g: 好不错，好喜欢啊？？？？？？？？？？？？？？？？？？？？？？？？？ | transfer_b: 一般般，根本没收到货，一般般
# -----------------------------------------------------------
# origin: 怎么<UNK>不了，怎么扣的 | reconstruct: 怎么只有一个<UNK>的，怎么不是很好
# transfer_g: 用<UNK><UNK><UNK><UNK><UNK>好吧<UNK><UNK><UNK><UNK><UNK><UNK><UNK> | transfer_b: 怎么只有一个，不是银的
# -----------------------------------------------------------
# origin: 好小好小呀，和想象的出入太大了 | reconstruct: 没想象的那么好，链子短了点
# transfer_g: 好漂亮好小好喜欢好喜欢好喜欢好喜欢啊。 | transfer_b: 没的链子，链子太短
# -----------------------------------------------------------
# origin: 不好看不好看 | reconstruct: 不知道是不是真的银
# transfer_g: 好看好看好看我喜欢好喜欢 | transfer_b: 不咋不合适
# -----------------------------------------------------------
# origin: 还行挺好看的 | reconstruct: 挺好看的 不错
# transfer_g: 不错挺好看的哦 | transfer_b: 大小合适 一般般
# ===========================================================
# epoch:12==================================================
# INFO:tensorflow:Restoring parameters from /root/VAE/char_vae_model/runs/1513220661/model-12
# restore /root/VAE/char_vae_model/runs/1513220661/model-12 success
# -----------------------------------------------------------
# 不实用，用不上
# 嗯，不知道好不好
# 嗯嗯，值这个价
# 不错，下次再来
# 不错，下次再来！
# 不错，下次再来！
# 很漂亮，价格实惠，值得购买
# 很漂亮，价格也不贵，值得购买。
# 很漂亮，价格实惠，值得购买。
# 很漂亮，价格实惠，值得推荐。
# 很漂亮，价格实惠，值得推荐。
# 很不错，做工精细，物有所值，值得购买，
# -----------------------------------------------------------
# 垃圾，发货慢的要死
# 垃圾，垃圾中的战斗机
# 垃圾，和想象中的差
# 垃圾，和想象的差
# 垃圾，和想象中的一样，
# 满意，质量很好，好评
# 好评，质量很好，和图片一样
# 不错，和图片一样，挺好的
# 不错，质量很好，发货快，满意
# 很漂亮，质量很好，价格实惠，满意
# 很漂亮，质量很好，价格实惠，非常满意
# 很不错，做工精细，物有所值，值得购买，
# good:质量很好 | bad:<UNK>
# -----------------------------------------------------------
# origin: 不错很合适 | reconstruct: 不错挺漂亮的
# transfer_g: 很不错质量不错 | transfer_b: 好看的
# -----------------------------------------------------------
# origin: 质量，不错，很美美哒拉风。 第二次购买了，发货很快，质量有保障 | reconstruct: 做工很精致，很漂亮，质量很好，价格也不贵，买了送女朋友的，她很喜欢
# transfer_g: 项链很漂亮，做工很精致，质量很不错，很喜欢，卖家发货速度很快，赞一个 | transfer_b: ，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 商品本身还行，就是有点卡头发 | reconstruct: 这个还行，就是容易刮到头发
# transfer_g: 这个项链很不错，做工很精致 | transfer_b: 塑料的，有一个就坏了
# -----------------------------------------------------------
# origin: 感觉还可以，不错，真心不错。 | reconstruct: 东西不错，感觉还不错，很喜欢。
# transfer_g: 东西质量不错哦，很不错，很不错哦 | transfer_b: 还行吧，没有图片好看。
# -----------------------------------------------------------
# origin: 送给情人的 非常满意 谢谢热情的卖家 | reconstruct: 非常喜欢 包装精美 好评
# transfer_g: 宝贝很喜欢 做工很精致 物美价廉 | transfer_b: 垃圾，超级满意的一次购物
# -----------------------------------------------------------
# origin: 老婆很喜欢，很满意。 | reconstruct: 很好看，我很喜欢
# transfer_g: 宝贝很不错很喜欢，很值得购买 | transfer_b: 不满意，没有图片上好看
# -----------------------------------------------------------
# origin: 太好了，不错很喜欢 | reconstruct: 满意，很好
# transfer_g: 很不错很好很喜欢 | transfer_b: 垃圾，垃圾垃圾
# -----------------------------------------------------------
# origin: 东西非常好，快递很快，昨天下的单今天就到了，谢谢了 | reconstruct: 东西非常的好，发货速度快，卖家态度好，快递也给力，全5分好评！
# transfer_g: 东西已经收到了，质量不错，卖家服务很好，发货速度很快，很满意的一次购物 | transfer_b: 骗人的，垃圾，垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾
# -----------------------------------------------------------
# origin: 下次还来，老板记得给打个折哦 | reconstruct: 卖家发货快，下次有机会再来。
# transfer_g: 卖家发货很快，东西很不错哦 | transfer_b: 骗子，以后有机会不要买
# -----------------------------------------------------------
# origin: 卡子挺漂亮的，就是太沉了 | reconstruct: 挺漂亮的，就是小了点
# transfer_g: 戒指质量不错做工精致 很喜欢 | transfer_b: 假的，假的
# -----------------------------------------------------------
# origin: 失望透了 | reconstruct: 太小了太小了
# transfer_g: 已经收到了质量很不错 | transfer_b: 垃圾的要死
# -----------------------------------------------------------
# origin: 大家不要买，质量又不好，感觉像**的地摊货 | reconstruct: 一点都不好，建议大家不要买，质量不好，以后还会再来的
# transfer_g: 戒指质量很好 色泽很好 价格实惠 卖家态度很好 值得购买 | transfer_b: 假的，垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾
# -----------------------------------------------------------
# origin: 速速慢啊 还没有送到 | reconstruct: 一般，没有想象中那么好
# transfer_g: 东西很不错哦 质量很好 | transfer_b: 垃圾，根本就没有送
# -----------------------------------------------------------
# origin: 没得说！ | reconstruct: 挺好的
# transfer_g: 质量很不错 | transfer_b: 垃圾的要死
# -----------------------------------------------------------
# origin: 快递太慢，女朋友不满意，<UNK>早日关门。 | reconstruct: 还没收到货，不知道怎么回事，我很生气
# transfer_g: 东西很不错，女朋友很喜欢，发货速度很快 | transfer_b: 不满意，差评，根本没收到就坏了
# -----------------------------------------------------------
# origin: 快递好慢！ 必须差评差评差评 差评差评差评 | reconstruct: 快递太慢了，圆通快递员快递员最差的要死
# transfer_g: 卖家发货很快 快递小哥服务很到位 快递速度很快 赞一个！ | transfer_b: 差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评
# -----------------------------------------------------------
# origin: 感觉差，边上好多<UNK>，稍微有点刮手，而且表面漆也不好 | reconstruct: 质量很好，每个都很好，细节处理得也很好，就是不知道会不会掉颜色
# transfer_g: 戒指质量很好 色泽很不错 外观很好看 做工很好 价格很便宜 | transfer_b: 不好，没有图片上的那么好看，一点都不好，不值这个价
# -----------------------------------------------------------
# origin: 质量不好，根本夹不住头发， | reconstruct: 绳子容易坏，不好用，老是掉漆
# transfer_g: 项链质量很好，戴着很舒服 | transfer_b: 不好，根本就坏的，要坏
# -----------------------------------------------------------
# origin: 垃圾东西，没想到在京东上也有垃圾货骗人 | reconstruct: 垃圾货，就大街垃圾堆垃圾堆垃圾堆垃圾堆垃圾堆垃圾堆垃圾堆垃圾堆，骗子
# transfer_g: 一直在这家店买东西，质量也不错，下次还来买 | transfer_b: 垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾
# -----------------------------------------------------------
# origin: 一点都不满意！特别是绳子！没用几天就断了！貔貅也成玻璃渣了！碎的！ | reconstruct: 一点都不满意，一点都不好，拿回来的时候都掉了，大家千万不要买
# transfer_g: 戒指已经收到了，质量很好，每个细节都很好，非常满意！ | transfer_b: 垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾
# -----------------------------------------------------------
# origin: 女款和网上图片不一样，字也刻歪了，有点长 | reconstruct: 珠子太小了，每个珠子都不对称，有点小失望
# transfer_g: 戒指已经收到了色泽很不错 做工很精致 色泽很不错 | transfer_b: 不咋的，根本没两天就掉颜色了
# -----------------------------------------------------------
# origin: 质量不怎么样 总体感觉还行吧 毕竟价格在那里 | reconstruct: 挺好的 价格也便宜 就是物流速度太慢了
# transfer_g: 东西不错 质量不错 价格实惠 卖家服务也很好 | transfer_b: 假的，假的也就那样吧
# -----------------------------------------------------------
# origin: 不实用，用不到。 | reconstruct: 不实用。。。。。。。。。。。。。。
# transfer_g: 价格很实惠，很喜欢。 | transfer_b: 垃圾，骗人的不想说。
# -----------------------------------------------------------
# origin: 实物与网上照片有差异，不太理想，真实点应该可以持久 | reconstruct: 实物与照片相差甚远，但总体来说还可以，物流也很慢
# transfer_g: 这款手链质量很不错，做工很精致，价格也很实惠 | transfer_b: 没有图片上的那么好看，根本就没有发票
# -----------------------------------------------------------
# origin: 买回来第二天就断了。换了送的皮筋。第3天又断了。。看来不适合我 | reconstruct: 本来想买的，结果只发了一个，不知道质量如何。请大家不要买。
# transfer_g: 项链已经收到了，质量很好哦，这个价格买到很划算。很喜欢。 | transfer_b: 骗人的，刚买回来就坏了。骗子骗子骗子骗子骗子骗子骗子骗子骗子骗子骗子骗子骗子骗子
# -----------------------------------------------------------
# origin: 有点重，物流有点慢，快递大哥辛苦了 | reconstruct: 收到了，就是物流有点慢。
# transfer_g: 戒指收到了，质量很不错，很漂亮很喜欢 | transfer_b: 不满意，没几天就坏了。
# -----------------------------------------------------------
# origin: 怎么<UNK>不了，怎么扣的 | reconstruct: 怎么说呢。不是很好看。
# transfer_g: 虽然有点小但是还是很不错的。 | transfer_b: 假的根本没有什么用。骗人的
# -----------------------------------------------------------
# origin: 好小好小呀，和想象的出入太大了 | reconstruct: 和想象中的差距太大了，其他还行
# transfer_g: 卖家服务很好，质量不错做工很好 | transfer_b: 垃圾的要死，垃圾的要死
# -----------------------------------------------------------
# origin: 不好看不好看 | reconstruct: 不好看不好看
# transfer_g: 价格实惠质量不错 | transfer_b: 不好看不好不好
# -----------------------------------------------------------
# origin: 还行挺好看的 | reconstruct: 挺好看的
# transfer_g: 质量很不错 很漂亮 | transfer_b: 不好，不好看
# ===========================================================
# epoch:13==================================================
# INFO:tensorflow:Restoring parameters from /root/VAE/char_vae_model/runs/1513220661/model-13
# restore /root/VAE/char_vae_model/runs/1513220661/model-13 success
# -----------------------------------------------------------
# 不实用，用不上
# 还没用，不知道怎么样
# 还没用，不知道怎么样
# 很好，下次再来
# 还行！！！！！！！！！！！！！！！！！
# 宝贝收到了，质量很好
# 宝贝收到了，质量很好，好评
# 宝贝收到了，质量不错，值得购买
# 宝贝收到了，质量不错，很喜欢
# 宝贝收到了，质量不错，非常满意。
# 宝贝收到了，质量不错，做工精致，满意
# 很不错，做工精细，物有所值，值得购买，
# -----------------------------------------------------------
# 垃圾，发货慢的要死
# 差评！！！！！！！！！！！！！！！
# 挺不错的，就是快递太慢了
# 挺好的，就是快递太慢了
# 挺好的，就是快递太慢了
# 挺好的！！！！！！！！！！！！
# 不错！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！
# 不错！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！
# 不错，挺好的！
# 不错，挺好的！
# 不错，挺好的！！！！！！！！！！！！！！！！！！！
# 很不错，做工精细，物有所值，值得购买，
# good:<UNK> | bad:差评，太小了
# -----------------------------------------------------------
# origin: 不错很合适 | reconstruct: 可以可以可以可以
# transfer_g: 很不错的 | transfer_b: 一般般，还可以
# -----------------------------------------------------------
# origin: 质量，不错，很美美哒拉风。 第二次购买了，发货很快，质量有保障 | reconstruct: 东西不错，质量很好，做工精致，很喜欢，下次还来买。
# transfer_g: 东西不错，很喜欢，买了好几次了，值得推荐 | transfer_b: 一般般，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 商品本身还行，就是有点卡头发 | reconstruct: 戒指质量不错，款式简单大方
# transfer_g: 项链材质不错做工很好 | transfer_b: 质量还可以，颜色也比较暗
# -----------------------------------------------------------
# origin: 感觉还可以，不错，真心不错。 | reconstruct: 东西不错，朋友很喜欢，下次还会再来
# transfer_g: 东西很不错哦，值得推荐 | transfer_b: 还没用呢，看着还不错，不知道时间长了怎么样
# -----------------------------------------------------------
# origin: 送给情人的 非常满意 谢谢热情的卖家 | reconstruct: 非常满意的一次购物，很喜欢，下次还会再来
# transfer_g: 东西很好，非常喜欢，值得推荐 | transfer_b: 不满意，说好的刻字呢，质量差，物流也慢
# -----------------------------------------------------------
# origin: 老婆很喜欢，很满意。 | reconstruct: 宝贝收到了，很好看，很喜欢。
# transfer_g: 项链很喜欢，很喜欢。 | transfer_b: 宝贝收到了，还没用，不知道怎么样。。。。。。。。。。。。。。。。。。。。。
# -----------------------------------------------------------
# origin: 太好了，不错很喜欢 | reconstruct: 很好很好很满意
# transfer_g: 东西不错很喜欢 | transfer_b: 一般般吧，实物与图片差别很大
# -----------------------------------------------------------
# origin: 东西非常好，快递很快，昨天下的单今天就到了，谢谢了 | reconstruct: 东西收到了，质量很好，和卖家描述的一样，下次还会再来
# transfer_g: 东西收到了，非常喜欢，和卖家描述的一样，值得信赖 | transfer_b: 物流太慢了，五天才到，太慢了，太慢了，等了一周才到，差评，差评差评差评差评差评差评差评差评差评
# -----------------------------------------------------------
# origin: 下次还来，老板记得给打个折哦 | reconstruct: 快递小哥辛苦了，等了好久才来评价
# transfer_g: 东西很好值得推荐哦 | transfer_b: 差评！还没一个月就降价！！！！！！！！！！！！！！！！！！！！！！！！
# -----------------------------------------------------------
# origin: 卡子挺漂亮的，就是太沉了 | reconstruct: 质量还行，就是物流太慢了
# transfer_g: 东西很好哦 | transfer_b: 没戴几天就断了，质量也不行
# -----------------------------------------------------------
# origin: 失望透了 | reconstruct: 太差劲了。。。。。。。。。
# transfer_g: 很好很喜欢 | transfer_b: 差评！根本没有收到货！差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差
# -----------------------------------------------------------
# origin: 大家不要买，质量又不好，感觉像**的地摊货 | reconstruct: 这个价钱买到这么好的东西，大家不要犹豫了
# transfer_g: 这个非常好，建议大家买 | transfer_b: ***，***********************，就当买个教训
# -----------------------------------------------------------
# origin: 速速慢啊 还没有送到 | reconstruct: 怎么说呢，没有想象中那么好
# transfer_g: 我很喜欢，谢谢 | transfer_b: 垃圾货，根本就没有收到货，还没用
# -----------------------------------------------------------
# origin: 没得说！ | reconstruct: 很好！！！！！！！
# transfer_g: 非常好 | transfer_b: 一般般，一般般
# -----------------------------------------------------------
# origin: 快递太慢，女朋友不满意，<UNK>早日关门。 | reconstruct: 发货速度太慢，快递员很给力！！！！！！！！！！！！！！！！！！！！！！
# transfer_g: 东西很好，女朋友很喜欢。 | transfer_b: 没收到货，根本没收到货，申请退款申请退款！！！！！！！！！！！！！！！！！！！！
# -----------------------------------------------------------
# origin: 快递好慢！ 必须差评差评差评 差评差评差评 | reconstruct: 物流太慢了 七八天才到 差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评
# transfer_g: 给女朋友买的，她很喜欢 | transfer_b: 差评！根本没收到货！差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评差评
# -----------------------------------------------------------
# origin: 感觉差，边上好多<UNK>，稍微有点刮手，而且表面漆也不好 | reconstruct: 东西很好，就是不小心掉地上地上就掉地上了，质量很好
# ...
# transfer_g: 戒指非常好非常漂亮非常喜欢。。。。。。。。。。。。。。。。。。。。。。。。 | transfer_b: 差评差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差！根本就掉漆了！根本不是银的！根本就
# -----------------------------------------------------------
# origin: 女款和网上图片不一样，字也刻歪了，有点长 | reconstruct: 一点都不满意，质量也不是很好，和图片上的不一样
# transfer_g: 戒指非常好，我非常喜欢，非常满意的一次购物 | transfer_b: 不咋地，根本就不是银的，根本不是银的，而且包装太简陋了
# -----------------------------------------------------------
# origin: 质量不怎么样 总体感觉还行吧 毕竟价格在那里 | reconstruct: 看着还行，就是不知道会不会褪色
# transfer_g: 东西很好哦，价格实惠 | transfer_b: 一般般吧，也就那样吧，一用力就坏了
# -----------------------------------------------------------
# origin: 不实用，用不到。 | reconstruct: 实用。。。。。。。。。。。
# transfer_g: 非常喜欢。 | transfer_b: 没用，不知道能不能退
# -----------------------------------------------------------
# origin: 实物与网上照片有差异，不太理想，真实点应该可以持久 | reconstruct: 实物与图片相差很大，略有失望，还不如不送
# transfer_g: 项链质量很好，卖家服务态度很好 | transfer_b: 实物与图片严重不符，根本没有照片上那么亮，还凑合，凑合吧
# -----------------------------------------------------------
# origin: 买回来第二天就断了。换了送的皮筋。第3天又断了。。看来不适合我 | reconstruct: 刚拿到手就坏了。。。。。。。。。。。。。。。。。。。。。。。。。
# transfer_g: 这个戒指我很喜欢。谢谢老板的小礼物。 | transfer_b: 没戴几天就坏了，还没两天就断了！！！！差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差差
# -----------------------------------------------------------
# origin: 有点重，物流有点慢，快递大哥辛苦了 | reconstruct: 质量太差了，没有图片上的好看。
# transfer_g: 东西很好，我很喜欢 | transfer_b: 太小了，根本没有发票，只有一根绳子，根本不值这个价！
# -----------------------------------------------------------
# origin: 怎么<UNK>不了，怎么扣的 | reconstruct: 不知道怎么用，放鱼缸里了
# transfer_g: 好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好 | transfer_b: 不咋滴，根本没怎么戴呢
# -----------------------------------------------------------
# origin: 好小好小呀，和想象的出入太大了 | reconstruct: 除了有点小，其他的都还好
# transfer_g: 戒指色泽很好，很喜欢 | transfer_b: 凑合吧，珠子太小了，实物与图片不符
# -----------------------------------------------------------
# origin: 不好看不好看 | reconstruct: 不知道会不会掉色
# transfer_g: 非常好非常喜欢 | transfer_b: 不咋滴，不知道会不会掉颜色
# -----------------------------------------------------------
# origin: 还行挺好看的 | reconstruct: <UNK>
# transfer_g: 戒指不错 | transfer_b: 一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般一般般
# ===========================================================
# epoch:14==================================================
# INFO:tensorflow:Restoring parameters from /root/VAE/char_vae_model/runs/1513220661/model-14
# restore /root/VAE/char_vae_model/runs/1513220661/model-14 success
# -----------------------------------------------------------
# 不实用，用不上
# 不错，挺好看的
# 不错，挺好看的
# 不错，挺好看的
# 不错，挺好看的
# 还不错，挺好的
# 还不错，挺好的
# 东西不错，值得购买
# 东西不错，值得购买
# 东西不错，物美价廉，值得购买
# 东西不错，物美价廉，值得购买
# 很不错，做工精细，物有所值，值得购买，
# -----------------------------------------------------------
# 垃圾，发货慢的要死
# 差评。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# 。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# 。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# 不错，就是物流慢了点
# 挺好的，就是物流太慢了。
# 不错，就是有点大了。
# 收到了，质量很好，做工精细，很满意。
# 收到了，质量很好，做工精细，很喜欢
# 收到了，质量很好，做工精细，很喜欢
# 收到了，质量很好，很漂亮，很喜欢
# 很不错，做工精细，物有所值，值得购买，
# good:东西收到了，挺好看的 | bad:太次了
# -----------------------------------------------------------
# origin: 不错很合适 | reconstruct: 不错不错不错
# transfer_g: 宝贝质量很好很不错 | transfer_b: 漂亮
# -----------------------------------------------------------
# origin: 质量，不错，很美美哒拉风。 第二次购买了，发货很快，质量有保障 | reconstruct: 宝贝收到了，质量很好，做工精细，带着很漂亮，同事们都说好看
# transfer_g: 项链真的很不错，戴着很好看，质量也很好，价格又实惠，很满意的一次购物。 | transfer_b: ，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 商品本身还行，就是有点卡头发 | reconstruct: 东西还行，就是有点小
# transfer_g: 这个东西很好用很好用，用起来很好看。 | transfer_b: <UNK>
# -----------------------------------------------------------
# origin: 感觉还可以，不错，真心不错。 | reconstruct: 还不错，挺好看的。
# transfer_g: 感觉感觉还不错，挺好看的，用起来也挺好看的。 | transfer_b: 不错，下次再买
# -----------------------------------------------------------
# origin: 送给情人的 非常满意 谢谢热情的卖家 | reconstruct: 挺好看的 送给女朋友的 她很喜欢
# transfer_g: 手链真的很不错 是我喜欢的款式 价格也很实惠 很满意的一次购物 | transfer_b: 满意 就是物流太慢了
# -----------------------------------------------------------
# origin: 老婆很喜欢，很满意。 | reconstruct: 很好看，就是有点小
# transfer_g: 项链款式很好看，色泽很不错，带着很好看，很喜欢 | transfer_b: 。。。。。。。。。。。。。。。。
# -----------------------------------------------------------
# origin: 太好了，不错很喜欢 | reconstruct: 很好很好很好很好
# transfer_g: 东西很不错很好很好很好很好很好很好很好很好很好很好很好很好很好很好 | transfer_b: 满意，值得购买
# -----------------------------------------------------------
# origin: 东西非常好，快递很快，昨天下的单今天就到了，谢谢了 | reconstruct: 给老婆买的情人节礼物，老婆很喜欢，就是快递慢了点
# transfer_g: 这个东西真的很不错哦，我很喜欢，而且也很好看的哦，下次还会再来的 | transfer_b: 太慢了，等了6天才到
# -----------------------------------------------------------
# origin: 下次还来，老板记得给打个折哦 | reconstruct: 挺好的，就是不知道以后会不会掉色
# transfer_g: 这个手链真的很好看，同事们都说很好看，也很好看，下次还会再来买的。 | transfer_b: 垃圾，两天就掉色了
# -----------------------------------------------------------
# origin: 卡子挺漂亮的，就是太沉了 | reconstruct: 链子太细了。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# transfer_g: 手链看着还不错，挺好看的。 | transfer_b: 。。。。。。。。。。。。。。。。。
# -----------------------------------------------------------
# origin: 失望透了 | reconstruct: 挺漂亮的
# transfer_g: 这款质量挺好的，挺好看的 | transfer_b: 难看
# -----------------------------------------------------------
# origin: 大家不要买，质量又不好，感觉像**的地摊货 | reconstruct: *******，***********************
# transfer_g: 这个东西挺好的，既便宜又便宜又便宜又便宜又便宜又便宜又便宜又便宜又便宜又便宜又便宜又实惠， | transfer_b: 垃圾，千万别买，垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾
# -----------------------------------------------------------
# origin: 速速慢啊 还没有送到 | reconstruct: 好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好好
# transfer_g: 东西也很好用，快递也很给力，东西也很好用 | transfer_b: 垃圾，无语了
# -----------------------------------------------------------
# origin: 没得说！ | reconstruct: 宝贝收到了，很喜欢
# transfer_g: 项链很好看，质量也不错，很喜欢 | transfer_b: 喜欢
# -----------------------------------------------------------
# origin: 快递太慢，女朋友不满意，<UNK>早日关门。 | reconstruct: 还可以，就是物流太慢了。
# transfer_g: 东西真的很不错，带起来很好看，也很有分量，很喜欢。 | transfer_b: 。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# -----------------------------------------------------------
# origin: 快递好慢！ 必须差评差评差评 差评差评差评 | reconstruct: 差评差评差评差评差评差评差评差评差评差评差评差评差评差评
# transfer_g: 这个赠品也不是很满意，也不知道会不会退色 | transfer_b: 差评差评差评差评差评差评
# -----------------------------------------------------------
# origin: 感觉差，边上好多<UNK>，稍微有点刮手，而且表面漆也不好 | reconstruct: 还可以，就是不知道会不会掉颜色，一点都不好，没有图片那么亮
# transfer_g: 这个手链很好看，也很有弹性，也很有质感，摸起来也很舒服，很舒服，很舒服。 | transfer_b: 不好，掉色，掉地上就掉了
# -----------------------------------------------------------
# origin: 质量不好，根本夹不住头发， | reconstruct: 挺好的，就是不知道掉不掉色
# transfer_g: 这个头绳很好看，扎头发也很好看，很实用，很好用。 | transfer_b: 掉色，掉色
# -----------------------------------------------------------
# origin: 垃圾东西，没想到在京东上也有垃圾货骗人 | reconstruct: 垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾
# transfer_g: 虽然是赠品，但我也是醉了吧，没有想到这么好的东西。 | transfer_b: 垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾
# -----------------------------------------------------------
# origin: 一点都不满意！特别是绳子！没用几天就断了！貔貅也成玻璃渣了！碎的！ | reconstruct: 太垃圾了，戴了不到半个月就掉色了，大家不要上当了，大家都不要上当了！！！！！！！！
# transfer_g: 这款头绳非常漂亮，质量也很好，戴在手上也很好看，同事们都说好看呢！非常满意的一次购物！ | transfer_b: 垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾
# -----------------------------------------------------------
# origin: 女款和网上图片不一样，字也刻歪了，有点长 | reconstruct: 实物与图片差别很大，不过还可以，就是不知道带久了会不会变色
# transfer_g: 这个手链质量很好，颜色也没有色差，戴起来也很好看，很满意的一次购物 | transfer_b: 差评 链子太细了 链子太细了
# -----------------------------------------------------------
# origin: 质量不怎么样 总体感觉还行吧 毕竟价格在那里 | reconstruct: 还可以吧 就是感觉有点贵 不值这个价
# transfer_g: 感觉还不错吧，也挺好看的，就是感觉有点小，不过也挺好看的 | transfer_b: 垃圾，没带几天就掉色了
# -----------------------------------------------------------
# origin: 不实用，用不到。 | reconstruct: 挺漂亮的，不知道会不会掉色
# transfer_g: 这个头绳非常好看，扎头发也很好看，非常喜欢。 | transfer_b: 假货，掉色
# -----------------------------------------------------------
# origin: 实物与网上照片有差异，不太理想，真实点应该可以持久 | reconstruct: 实物与图片相差较大，但总体来说还可以吧。
# transfer_g: 这个手链看起来很好看，戴起来感觉也很有气质，价格也实惠，很满意的一次购物。 | transfer_b: 差评。。。。。。。。。。。。。。。。。。。
# -----------------------------------------------------------
# origin: 买回来第二天就断了。换了送的皮筋。第3天又断了。。看来不适合我 | reconstruct: 链子太短了，戴了半个月才来评价，不知道该怎么搞活动就断了。。。。。。。。。。。
# transfer_g: 这个手链很好看，戴着也很舒服，而且质量也很好，我很喜欢这种类型的感觉。 | transfer_b: 差评，戴了不到一个月不到链子就断了，懒得换了
# -----------------------------------------------------------
# origin: 有点重，物流有点慢，快递大哥辛苦了 | reconstruct: 送的东西也很好！！！！！！！！！！！！！！！！！！！！！！！！！
# transfer_g: 东西还是很不错的，用起来也很好看，很满意的一次购物。 | transfer_b: 。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# -----------------------------------------------------------
# origin: 怎么<UNK>不了，怎么扣的 | reconstruct: <UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK>
# transfer_g: 我只能说<UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK><UNK> | transfer_b: 垃圾，破破玩意
# -----------------------------------------------------------
# origin: 好小好小呀，和想象的出入太大了 | reconstruct: 挺好的，就是有点小
# transfer_g: 这个东西很好用也很好用很好用很好用不错不错不错不错不错不错不错不错不错 | transfer_b: 不好，没带几天就断了
# -----------------------------------------------------------
# origin: 不好看不好看 | reconstruct: 不好看
# transfer_g: 感觉不是很好看 | transfer_b: 掉色
# -----------------------------------------------------------
# origin: 还行挺好看的 | reconstruct: 还可以吧，没有想象中的好
# transfer_g: 东西感觉还不错，挺好看的，也挺好看的 | transfer_b: ，，，，，，，，
# ===========================================================
# epoch:15==================================================
# INFO:tensorflow:Restoring parameters from /root/VAE/char_vae_model/runs/1513220661/model-15
# restore /root/VAE/char_vae_model/runs/1513220661/model-15 success
# -----------------------------------------------------------
# 不实用，用不上
# 太小了，带不了
# 挺好的，就是不太会用
# 挺好的，就是有点小
# 还可以，就是有点大了
# 还可以，就是小了点
# 还可以，就是小了点
# 还不错，挺喜欢的
# 还不错，挺喜欢的
# 还不错，女朋友很喜欢
# 还不错，女朋友很喜欢
# 很不错，做工精细，物有所值，值得购买，
# -----------------------------------------------------------
# 垃圾，发货慢的要死
# 垃圾 垃圾 垃圾 垃圾
# 物流太慢了，其他都还好
# 物流太慢了，其他都还好
# 物流太慢了，其他的都还好
# 物流太慢了，其他的都还好
# 东西收到了，质量很好，物流也快
# 东西收到了，质量很好，物流也快，好评
# 宝贝收到了，质量很好，很满意
# 宝贝收到了，质量很好，做工精细，很满意
# 宝贝收到了，质量很好，做工精细，很满意
# 很不错，做工精细，物有所值，值得购买，
# good:丑丑丑丑丑丑丑丑丑丑 | bad:<UNK>
# -----------------------------------------------------------
# origin: 不错很合适 | reconstruct: <UNK>
# transfer_g: 阔以阔以阔以阔以阔 | transfer_b: ！！！！！！！！！！！！！！！！！
# -----------------------------------------------------------
# origin: 质量，不错，很美美哒拉风。 第二次购买了，发货很快，质量有保障 | reconstruct: 宝贝收到了，质量很好，做工精细，外观漂亮，价格比实体店便宜很多
# transfer_g: 手链质量很好做工精致外观漂亮色泽光亮戴在手上很好看价格也不贵下次有需要会再来买的 | transfer_b: ，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 商品本身还行，就是有点卡头发 | reconstruct: 这个还可以吧，就是有点小
# transfer_g: 项链戴在脖子上很有气质&#183;&#183;&#183; | transfer_b: 还可以吧，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 感觉还可以，不错，真心不错。 | reconstruct: 还可以，，，，，，，
# transfer_g: 手链很好看也很好看 | transfer_b: 不错，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 送给情人的 非常满意 谢谢热情的卖家 | reconstruct: 项链很漂亮，很满意的一次购物
# transfer_g: 项链戴上很好看朋友们都说我眼光也很好 | transfer_b: 好评，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 老婆很喜欢，很满意。 | reconstruct: 第一次在网上购物，，，，，，，，，
# transfer_g: 这款项链戴在手上很好看 | transfer_b: ，，，，，，，，
# -----------------------------------------------------------
# origin: 太好了，不错很喜欢 | reconstruct: 很好看 很喜欢
# transfer_g: 手链很好看戴在手上也很好看 | transfer_b: 好评，，，，，
# -----------------------------------------------------------
# origin: 东西非常好，快递很快，昨天下的单今天就到了，谢谢了 | reconstruct: 宝贝收到了，比我想象中的还要好。
# transfer_g: 项链很好看···························· | transfer_b: 送的东西，很好，谢谢！
# -----------------------------------------------------------
# origin: 下次还来，老板记得给打个折哦 | reconstruct: 东西很好，朋友们都说好看
# transfer_g: 项链戴起来很好看；朋友们都问我在哪里买一个嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻嘻 | transfer_b: 好评，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 卡子挺漂亮的，就是太沉了 | reconstruct: 东西还行，就是不知道会不会掉色
# transfer_g: 刚开始E5%92%AF%E5%A5%BD%E5%92%E5%90%A7%E3%80%82 | transfer_b: 辣鸡！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！
# -----------------------------------------------------------
# origin: 失望透了 | reconstruct: 挺好的&hellip;
# transfer_g: 我静静静静》》》》》》》》》》》》》》》》》》》》》》》》》》》》 | transfer_b: 垃圾！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！
# -----------------------------------------------------------
# origin: 大家不要买，质量又不好，感觉像**的地摊货 | reconstruct: 没想到这么便宜的东西，这么便宜又便宜又便宜，买了这么多东西。
# transfer_g: %E5%92%AF%E5%A5%BD%E5%B0%B1%E5%A5%BD%E5%B0%B1%E5%90%A7%E3%80%82%E4%B8%80%E8%88%AC%EF%BC%81 | transfer_b: 一如既往的好，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 速速慢啊 还没有送到 | reconstruct: 太差了，一点都不好
# transfer_g: %E5%A5%BD%E7%9A%84%E5%A4%AF%E5%A5%AF%E5%A5%BD% | transfer_b: 垃圾，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 没得说！ | reconstruct: 还行吧，就是太小了
# transfer_g: 感觉还可以就是有点小 | transfer_b: ，，，，，，，，
# -----------------------------------------------------------
# origin: 快递太慢，女朋友不满意，<UNK>早日关门。 | reconstruct: 东西收到了，还可以，就是不知道掉不掉色。
# transfer_g: 项链很好看但是戴在脖子上显得脖子上显得脖子有点痒磨脖子上了 | transfer_b: ，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 快递好慢！ 必须差评差评差评 差评差评差评 | reconstruct: 差差差，说好的刻字都没刻，差评差评差评差评差评
# transfer_g: 东西还可以》》》》》》》》》》》》》》》》》》》》》》》》》》》》 | transfer_b: 差评，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 感觉差，边上好多<UNK>，稍微有点刮手，而且表面漆也不好 | reconstruct: 一点都不好，带了几天就掉了，而且也不是很好。
# transfer_g: &#183<UNK>&#183;&#183;&#183;&#183;&#183;&#183;&#183;&#183;&#183;&# | transfer_b: 不好，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 质量不好，根本夹不住头发， | reconstruct: 一点都不好，容易掉漆。
# transfer_g: 颜色不是很好看有两三个没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲没劲 | transfer_b: 差，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 垃圾东西，没想到在京东上也有垃圾货骗人 | reconstruct: 垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾垃圾
# transfer_g: 嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯嚯 | transfer_b: 垃圾，垃圾，垃圾，垃圾，垃圾
# -----------------------------------------------------------
# origin: 一点都不满意！特别是绳子！没用几天就断了！貔貅也成玻璃渣了！碎的！ | reconstruct: 太差劲了，根本就不是银的，根本就不是银的，带了一天就掉漆了。
# transfer_g: 一点都不好刚买回来就掉钻掉钻掉颜色不掉颜色不知道掉不掉颜色不掉颜色不掉颜色不掉颜色不 | transfer_b: 垃圾，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 女款和网上图片不一样，字也刻歪了，有点长 | reconstruct: 宝贝收到了 质量很好 做工精细 很满意
# transfer_g: 项链戴在脖子上很好看&#183;&#183;&#183;&#183;&#183;&#183;&#183;&#183; | transfer_b: 太慢了，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 质量不怎么样 总体感觉还行吧 毕竟价格在那里 | reconstruct: 还可以吧，就是绳子有点长
# transfer_g: 看着还可以；；；；；；；；；；；；；；；；；；；；；；；；；；；； | transfer_b: 一般吧，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 不实用，用不到。 | reconstruct: 不好，不知道会不会退色
# transfer_g: 戴在脖子上很有气质&#183;&#183;&#183;&#183;&#183; | transfer_b: 垃圾，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 实物与网上照片有差异，不太理想，真实点应该可以持久 | reconstruct: 实物与图片有较大差距，但总体来说还可以。
# transfer_g: %E8%BF%98%E5%A5%BD%EF%BC%8C%E5%A5%BD%EF%BC%8C%E5%BE%88%E5%A5%BD%EF%BC%8C%E5%BE%88%E5%A5%BD% | transfer_b: 物流快，服务好。。。。。。。。。。。。。。。。。。。。。。。。。。
# -----------------------------------------------------------
# origin: 买回来第二天就断了。换了送的皮筋。第3天又断了。。看来不适合我 | reconstruct: 戴了一个礼拜才来评价。。。。。。。。。。。。。。。。。。。。。。。。
# transfer_g: 兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔兔 | transfer_b: 。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# -----------------------------------------------------------
# origin: 有点重，物流有点慢，快递大哥辛苦了 | reconstruct: 不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错不错
# transfer_g: 东西还不错》》》》》》》》》》》》》》》》》》》》》》》》》》》》 | transfer_b: 不错！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！
# -----------------------------------------------------------
# origin: 怎么<UNK>不了，怎么扣的 | reconstruct: 怎么说呢？？？？？？？？？？？？？？？？？？？？？？？？？？？？
# transfer_g: 刚拿回来就<UNK>减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥减肥 | transfer_b: 。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。。
# -----------------------------------------------------------
# origin: 好小好小呀，和想象的出入太大了 | reconstruct: 挺好的，就是大了点
# transfer_g: 很好看就是带在脖子上感觉有点大一点就更好了 | transfer_b: 好，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 不好看不好看 | reconstruct: 太小了，不知道会不会掉色
# transfer_g: 带在脖子上不好看 | transfer_b: ，，，，，，，，，，，，，
# -----------------------------------------------------------
# origin: 还行挺好看的 | reconstruct: 很漂亮，很喜欢
# transfer_g: 手链很好看就是有点点小 | transfer_b: ，，，，，，，，，
# ===========================================================
